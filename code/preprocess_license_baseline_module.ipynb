# %% [markdown]
# # 추가 데이터 수집
# - https://www.localdata.go.kr/devcenter/dataDown.do?menuNo=20001
# - 서울특별시 데이터 다운로드
# - 기준일 : 최초 인허가 ~ 2025-7-31
# - 필수 확인 데이터 : 목욕장업, 수영장업, 세탁업
# - 추가 확인 데이터 : 미용업, 이용업, 종합체육시설업 등 확인필요

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1. 목욕장업 인허가 데이터
#
# - 대중목욕탕, 찜질방, 사우나 등 물로 목욕 할 수 있거나 맥반석ㆍ황토 등에게 발생되는 열기 또는 원적외선 등을 이용하여 땀을 낼 수 있는 시설 및 설비 등의 서비스를 제공하는 업소정보
# - '6110000_서울특별시_11_44_01_P_목욕장업.csv'

# %%
data = pd.read_csv('../data/raw/add/6110000_CSV/6110000_서울특별시_11_44_01_P_목욕장업.csv', encoding='cp949')
data
# Out:
#         번호 개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호       인허가일자  \
# 0        1   목욕장업  11_44_01_P   3000000  3000000-202-2019-00001  2019-08-22
# 1        2   목욕장업  11_44_01_P   3000000  3000000-202-2024-00001  2024-07-22
# 2        3   목욕장업  11_44_01_P   3000000  3000000-202-1970-00392  1970-10-07
# 3        4   목욕장업  11_44_01_P   3000000  3000000-202-1963-00410  1963-06-13
# 4        5   목욕장업  11_44_01_P   3000000  3000000-202-2003-00009  2003-10-13
# ...    ...    ...         ...       ...                     ...         ...
# 3945  3946   목욕장업  11_44_01_P   3240000  3240000-202-1988-00234  1988-02-17
# 3946  3947   목욕장업  11_44_01_P   3240000  3240000-202-1987-00274  1987-12-11
# 3947  3948   목욕장업  11_44_01_P   3240000  3240000-202-1994-00263  1994-09-16
# 3948  3949   목욕장업  11_44_01_P   3240000  3240000-202-1983-00202  1983-12-22
# 3949  3950   목욕장업  11_44_01_P   3240000  3240000-202-2018-00002  2018-08-16
#
#       인허가취소일자  영업상태구분코드  영업상태명  상세영업상태코드  ...  욕실수 발한실여부  조건부허가신고사유  \
# 0         NaN         1  영업/정상         1  ...  0.0     N        NaN
# 1         NaN         1  영업/정상         1  ...  8.0     Y        NaN
# 2         NaN         1  영업/정상         1  ...  NaN     N        NaN
# 3         NaN         1  영업/정상         1  ...  0.0     N        NaN
# 4         NaN         1  영업/정상         1  ...  NaN     N        NaN
# ...       ...       ...    ...       ...  ...  ...   ...        ...
# 3945      NaN         3     폐업         2  ...  0.0     N        NaN
# 3946      NaN         3     폐업         2  ...  0.0     N        NaN
# 3947      NaN         3     폐업         2  ...  2.0     Y        NaN
# 3948      NaN         3     폐업         2  ...  2.0     Y        NaN
# 3949      NaN         3     폐업         2  ...  6.0     N        NaN
#
#       조건부허가시작일자  조건부허가종료일자 건물소유구분명  여성종사자수 남성종사자수 다중이용업소여부 Unnamed: 44
# 0           NaN        NaN     NaN     0.0    0.0        N         NaN
# 1           NaN        NaN      자가     0.0    0.0        N         NaN
# 2           NaN        NaN     NaN     NaN    NaN        N         NaN
# 3           NaN        NaN     NaN     0.0    0.0        N         NaN
# 4           NaN        NaN     NaN     NaN    NaN        N         NaN
# ...         ...        ...     ...     ...    ...      ...         ...
# 3945        NaN        NaN     NaN     NaN    NaN        N         NaN
# 3946        NaN        NaN     NaN     NaN    NaN        N         NaN
# 3947        NaN        NaN      임대     NaN    NaN        N         NaN
# 3948        NaN        NaN      임대     NaN    NaN        N         NaN
# 3949        NaN        NaN      자가     0.0    0.0        N         NaN
#
# [3950 rows x 45 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3950 entries, 0 to 3949
# Data columns (total 45 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   번호               3950 non-null   int64
#  1   개방서비스명           3950 non-null   object
#  2   개방서비스아이디         3950 non-null   object
#  3   개방자치단체코드         3950 non-null   int64
#  4   관리번호             3950 non-null   object
#  5   인허가일자            3950 non-null   object
#  6   인허가취소일자          0 non-null      float64
#  7   영업상태구분코드         3950 non-null   int64
#  8   영업상태명            3950 non-null   object
#  9   상세영업상태코드         3950 non-null   int64
#  10  상세영업상태명          3950 non-null   object
#  11  폐업일자             3285 non-null   object
#  12  휴업시작일자           0 non-null      float64
#  13  휴업종료일자           0 non-null      float64
#  14  재개업일자            0 non-null      float64
#  15  소재지전화            3671 non-null   object
#  16  소재지면적            3946 non-null   float64
#  17  소재지우편번호          3945 non-null   object
#  18  소재지전체주소          3945 non-null   object
#  19  도로명전체주소          1501 non-null   object
#  20  도로명우편번호          1451 non-null   float64
#  21  사업장명             3950 non-null   object
#  22  최종수정시점           3950 non-null   object
#  23  데이터갱신구분          3950 non-null   object
#  24  데이터갱신일자          3950 non-null   object
#  25  업태구분명            3950 non-null   object
#  26  좌표정보x(epsg5174)  3462 non-null   float64
#  27  좌표정보y(epsg5174)  3462 non-null   float64
#  28  위생업태명            3950 non-null   object
#  29  건물지상층수           3016 non-null   float64
#  30  건물지하층수           2878 non-null   float64
#  31  사용시작지상층          2644 non-null   float64
#  32  사용끝지상층           1550 non-null   float64
#  33  사용시작지하층          2558 non-null   float64
#  34  사용끝지하층           1441 non-null   float64
#  35  욕실수              2840 non-null   float64
#  36  발한실여부            3949 non-null   object
#  37  조건부허가신고사유        5 non-null      object
#  38  조건부허가시작일자        3 non-null      float64
#  39  조건부허가종료일자        3 non-null      float64
#  40  건물소유구분명          833 non-null    object
#  41  여성종사자수           663 non-null    float64
#  42  남성종사자수           663 non-null    float64
#  43  다중이용업소여부         3950 non-null   object
#  44  Unnamed: 44      0 non-null      float64
# dtypes: float64(20), int64(4), object(21)
# memory usage: 1.4+ MB

# %%
data.columns
# Out:
# Index(['번호', '개방서비스명', '개방서비스아이디', '개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자',
#        '영업상태구분코드', '영업상태명', '상세영업상태코드', '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자',
#        '재개업일자', '소재지전화', '소재지면적', '소재지우편번호', '소재지전체주소', '도로명전체주소', '도로명우편번호',
#        '사업장명', '최종수정시점', '데이터갱신구분', '데이터갱신일자', '업태구분명', '좌표정보x(epsg5174)',
#        '좌표정보y(epsg5174)', '위생업태명', '건물지상층수', '건물지하층수', '사용시작지상층', '사용끝지상층',
#        '사용시작지하층', '사용끝지하층', '욕실수', '발한실여부', '조건부허가신고사유', '조건부허가시작일자',
#        '조건부허가종료일자', '건물소유구분명', '여성종사자수', '남성종사자수', '다중이용업소여부', 'Unnamed: 44'],
#       dtype='object')

# %%
data['영업상태구분코드'].value_counts()
# Out:
# 영업상태구분코드
# 3    3285
# 1     665
# Name: count, dtype: int64

# %%
data['상세영업상태명'].value_counts()
# Out:
# 상세영업상태명
# 폐업    3285
# 영업     665
# Name: count, dtype: int64

# %%
data['영업상태명'].value_counts()
# Out:
# 영업상태명
# 폐업       3285
# 영업/정상     665
# Name: count, dtype: int64

# %%
data['위생업태명'].value_counts() # 삭제해도 될듯
# Out:
# 위생업태명
# 공동탕업              3187
# 공동탕업+찜질시설서비스영업     336
# 목욕장업 기타            168
# 한증막업               164
# 찜질시설서비스영업           95
# Name: count, dtype: int64

# %%
data['업태구분명'].value_counts() # 삭제해도 될듯
# Out:
# 업태구분명
# 공동탕업              3187
# 공동탕업+찜질시설서비스영업     336
# 목욕장업 기타            168
# 한증막업               164
# 찜질시설서비스영업           95
# Name: count, dtype: int64

# %%
### 컬럼 제거 ###
# info 정보 기준 널값이 대다수인 경우 + 불필요한 컬럼('위생업태명', '소재지전화', ...)
# 우편번호는 상세주소 있으므로 제거
# 겹치는 정보 제거 : '영업상태구분코드', '상세영업상태코드', '영업상태명'
'''
'번호', '개방서비스아이디', '개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자',
'영업상태구분코드', '영업상태명', '상세영업상태코드','휴업시작일자', '휴업종료일자',
'재개업일자', '소재지전화', '소재지우편번호', '도로명우편번호',
'최종수정시점', '데이터갱신구분', '데이터갱신일자', '업태구분명', '위생업태명', 
'건물지상층수', '건물지하층수', '사용시작지상층', '사용끝지상층','사용시작지하층', '사용끝지하층', 
'조건부허가신고사유', '조건부허가시작일자', '조건부허가종료일자', 
'건물소유구분명', 'Unnamed: 44'
'''




data = data.drop(columns=['번호', '개방서비스아이디', '개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자',
                          '영업상태구분코드', '영업상태명', '상세영업상태코드','휴업시작일자', '휴업종료일자',
                          '재개업일자', '소재지전화', '소재지우편번호', '도로명우편번호',
                          '최종수정시점', '데이터갱신구분', '데이터갱신일자', '업태구분명', '위생업태명', 
                          '건물지상층수', '건물지하층수', '사용시작지상층', '사용끝지상층','사용시작지하층', '사용끝지하층', 
                          '조건부허가신고사유', '조건부허가시작일자', '조건부허가종료일자', 
                          '건물소유구분명','Unnamed: 44'], 
                          axis=1)
data.columns
# Out:
# Index(['개방서비스명', '상세영업상태명', '폐업일자', '소재지면적', '소재지전체주소', '도로명전체주소', '사업장명',
#        '좌표정보x(epsg5174)', '좌표정보y(epsg5174)', '욕실수', '발한실여부', '여성종사자수',
#        '남성종사자수', '다중이용업소여부'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3950 entries, 0 to 3949
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   개방서비스명           3950 non-null   object
#  1   상세영업상태명          3950 non-null   object
#  2   폐업일자             3285 non-null   object
#  3   소재지면적            3946 non-null   float64
#  4   소재지전체주소          3945 non-null   object
#  5   도로명전체주소          1501 non-null   object
#  6   사업장명             3950 non-null   object
#  7   좌표정보x(epsg5174)  3462 non-null   float64
#  8   좌표정보y(epsg5174)  3462 non-null   float64
#  9   욕실수              2840 non-null   float64
#  10  발한실여부            3949 non-null   object
#  11  여성종사자수           663 non-null    float64
#  12  남성종사자수           663 non-null    float64
#  13  다중이용업소여부         3950 non-null   object
# dtypes: float64(6), object(8)
# memory usage: 432.2+ KB

# %%
data['폐업일자'] = pd.to_datetime(data['폐업일자'], errors='coerce')

# 폐업일자가 있고 & 2017-01-01 이전인 경우 제거
mask_drop = data['폐업일자'].notna() & (data['폐업일자'] < pd.Timestamp('2017-01-01'))

data = data[~mask_drop]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1207 entries, 0 to 3949
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   개방서비스명           1207 non-null   object
#  1   상세영업상태명          1207 non-null   object
#  2   폐업일자             542 non-null    datetime64[ns]
#  3   소재지면적            1207 non-null   float64
#  4   소재지전체주소          1202 non-null   object
#  5   도로명전체주소          1205 non-null   object
#  6   사업장명             1207 non-null   object
#  7   좌표정보x(epsg5174)  1192 non-null   float64
#  8   좌표정보y(epsg5174)  1192 non-null   float64
#  9   욕실수              1049 non-null   float64
#  10  발한실여부            1207 non-null   object
#  11  여성종사자수           661 non-null    float64
#  12  남성종사자수           661 non-null    float64
#  13  다중이용업소여부         1207 non-null   object
# dtypes: datetime64[ns](1), float64(6), object(7)
# memory usage: 141.4+ KB

# %%
### 소재지전체주소, 도로명전체주소 상호보완 ###
# '소재지전체주소'의 NaN 값을 '도로명전체주소' 값으로 채우기
data['소재지전체주소'] = data['소재지전체주소'].fillna(data['도로명전체주소'])

# '도로명전체주소'의 NaN 값을 '소재지전체주소' 값으로 채우기
data['도로명전체주소'] = data['도로명전체주소'].fillna(data['소재지전체주소'])

data.isna().sum()
# Out:
# 개방서비스명               0
# 상세영업상태명              0
# 폐업일자               665
# 소재지면적                0
# 소재지전체주소              0
# 도로명전체주소              0
# 사업장명                 0
# 좌표정보x(epsg5174)     15
# 좌표정보y(epsg5174)     15
# 욕실수                158
# 발한실여부                0
# 여성종사자수             546
# 남성종사자수             546
# 다중이용업소여부             0
# dtype: int64

# %%
### 소재지전체주소, 도로명전체주소 패턴 파악결과 공백 기준 4번째까지가 건물 주소임, 그 이후는 상세라서 4번째 까지만 인덱싱 ###
# 소재지전체주소
data['소재지전체주소'] = data['소재지전체주소'].str.split().str[:4].str.join(' ')

# 도로명전체주소
data['도로명전체주소'] = data['도로명전체주소'].str.split().str[:4].str.join(' ')

data[['소재지전체주소', '도로명전체주소']]
# Out:
#                      소재지전체주소               도로명전체주소
# 0      서울특별시 종로구 원남동 49-17번지    서울특별시 종로구 율곡로 180,
# 1       서울특별시 종로구 창신동 328-18     서울특별시 종로구 지봉로 19,
# 2      서울특별시 종로구 통인동 147-4번지   서울특별시 종로구 자하문로 35-6
# 3        서울특별시 종로구 창신동 578-1      서울특별시 종로구 창신길 22
# 4       서울특별시 종로구 관훈동 197-28    서울특별시 종로구 인사동7길 12
# ...                      ...                   ...
# 3896   서울특별시 강동구 천호동 410-105     서울특별시 강동구 진황도로 18
# 3911  서울특별시 강동구 암사동 421-23번지  서울특별시 강동구 구천면로 371-5
# 3912  서울특별시 강동구 암사동 514-55번지    서울특별시 강동구 상암로4길 52
# 3941     서울특별시 강동구 성내동 549-4      서울특별시 강동구 성내로 52
# 3949  서울특별시 강동구 성내동 127-25번지    서울특별시 강동구 천호옛8길 11
#
# [1207 rows x 2 columns]

# %%
### 주소 뒤에 ',' 있는 값들 ',' 기준으로 뒤에 제거 + ',' 제거
# ',' 뒤의 정보 제거 + 공백 제거까지 포함
data['소재지전체주소'] = data['소재지전체주소'].str.split(',').str.get(0).str.strip()
data['도로명전체주소'] = data['도로명전체주소'].str.split(',').str.get(0).str.strip()

data[['소재지전체주소', '도로명전체주소']]
# Out:
#                      소재지전체주소               도로명전체주소
# 0      서울특별시 종로구 원남동 49-17번지     서울특별시 종로구 율곡로 180
# 1       서울특별시 종로구 창신동 328-18      서울특별시 종로구 지봉로 19
# 2      서울특별시 종로구 통인동 147-4번지   서울특별시 종로구 자하문로 35-6
# 3        서울특별시 종로구 창신동 578-1      서울특별시 종로구 창신길 22
# 4       서울특별시 종로구 관훈동 197-28    서울특별시 종로구 인사동7길 12
# ...                      ...                   ...
# 3896   서울특별시 강동구 천호동 410-105     서울특별시 강동구 진황도로 18
# 3911  서울특별시 강동구 암사동 421-23번지  서울특별시 강동구 구천면로 371-5
# 3912  서울특별시 강동구 암사동 514-55번지    서울특별시 강동구 상암로4길 52
# 3941     서울특별시 강동구 성내동 549-4      서울특별시 강동구 성내로 52
# 3949  서울특별시 강동구 성내동 127-25번지    서울특별시 강동구 천호옛8길 11
#
# [1207 rows x 2 columns]

# %%
### 행정동 추출 위해 ###

# 필수 라이브러리 import 및 기본 상수/엔드포인트 설정
# 주소 문자열 전처리 함수
# 외부 API(행안부/카카오) 호출 래퍼에 간단한 캐시 적용

import re, time, threading, requests, pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed

# API 키
JUSO_KEY  = "devU01TX0FVVEgyMDI1MDgxMjE3MjIzMjExNjA2MjU=" # 도로표준화 때 사용 
KAKAO_KEY = "d86a315467c1c7369d876fd654b23cd0" # 행정동 추출할때 사용

# 엔드포인트 및 공통 HTTP 헤더
JUSO_URL   = "https://www.juso.go.kr/addrlink/addrLinkApi.do"  # 행안부 주소 표준화 API 
ADDR_URL   = "https://dapi.kakao.com/v2/local/search/address.json"  # 카카오 주소→좌표
REGION_URL = "https://dapi.kakao.com/v2/local/geo/coord2regioncode.json"  # 카카오 좌표→행정/법정동
HEADERS    = {"Authorization": f"KakaoAK {KAKAO_KEY}"}  # 카카오 인증 헤더

# 동시성 & 타임아웃
CONC_JUSO  = 12     # 행안부는 10~15 권장
CONC_KAKAO = 25     # 카카오는 20~30 권장
TIMEOUT = 7         # 각 요청의 타임아웃(초)
MAX_RETRY = 3       # 네트워크 오류 시 재시도 횟수(총 시도 = MAX_RETRY+1)
MAX_SHRINK = 12     # 뒤에서 1글자씩 줄이는 최대 시도 횟수 

## 문자열 가공
def norm_addr(s: str):
    """
    주소 문자열의 기본 정규화:
    - 입력이 문자열이 아니면 None 반환
    - 양 끝 공백 제거, 중복 공백을 단일 공백으로 축소
    - 결과가 빈 문자열이면 None
    """
    if not isinstance(s, str): return None
    s = re.sub(r"\s+", " ", s.strip())
    return s if s else None

def remove_trailing_bunji(s: str):
    """
    주소 문자열 끝이 정확히 '번지'로 끝나는 경우 그 부분만 제거
    - 카카오/행안부에서 '번지' 유무에 따라 매칭 실패하는 경우가 있어 후보 다양화 목적
    """
    if not isinstance(s, str): return None
    s = s.strip()
    return s[:-2].strip() if s.endswith("번지") else s

def cut_before_last_dash(s: str):
    """
    마지막 '-' 앞까지만 남김 (예: '67-138'→'67', '257-48번지'→'257번지')
    - 너무 세밀한 부번/호수 등은 제거하여 매칭률을 높이려는 전략
    """
    if not isinstance(s, str): return None
    m = re.search(r"^(.*?)(?:-\d+)(?:번지)?\s*$", s)
    return m.group(1).strip() if m else s

def progressive_shrink(s: str, max_try=MAX_SHRINK):
    """
    뒤에서 1글자씩 줄여가며 후보 생성 (너무 짧아지지 않게 컷오프)
    - 지나치게 짧아지는 것을 방지하기 위해 최소 길이(min_len) 설정
    - 경험적으로 '...구' 지점까지는 남기는 것이 지역 매칭에 유리해 컷오프에 반영
    """
    s0 = norm_addr(s)
    if not s0: return []
    # '구'의 위치를 찾고, 없으면 -1 → +1로 0이 됨; 최소 8자 보장
    min_len = max(8, s0.find("구")+1)  # '...구'까지는 남기자(대략적인 컷오프)
    out, cur = [], s0
    for _ in range(max_try):
        if len(cur) <= min_len: break
        cur = cur[:-1].rstrip()
        out.append(cur)
    return out

## 행안부 표준화 호출
std_cache, std_lock = {}, threading.Lock() # 같은 입력에 대한 중복 API 호출을 피하기 위해 스레드 세이프 캐시 사용
def juso_standardize(addr: str):
    """
    주소(지번/도로명 무관) -> 표준 도로명주소 or None 
    - 내부 캐시(std_cache)로 동일 주소 반복 호출 방지
    - 네트워크 오류 등 발생 시 재시도 (MAX_RETRY 기준)
    """
    
    if not addr: return addr, None
    a = norm_addr(addr)
    if not a: return addr, None
    with std_lock:
        if a in std_cache: return a, std_cache[a]
    params = {'confmKey': JUSO_KEY, 'currentPage':1, 'countPerPage':1,
              'keyword': a, 'resultType':'json'}
    out = None

    # 재시도 루프 (최대 MAX_RETRY+1회)
    for attempt in range(1, MAX_RETRY+2):
        try:
            r = requests.get(JUSO_URL, params=params, timeout=TIMEOUT); r.raise_for_status()
            j = r.json().get('results',{}).get('juso',[])
            out = j[0].get('roadAddr') if j else None # 최상위 후보 1건만 사용
            break
        except Exception:
            # 마지막 시도가 아니면 지수적 대기 후 재시도
            if attempt == MAX_RETRY+1: out = None
            else: time.sleep(0.5*attempt)
    
    # 캐시에 저장
    with std_lock:
        std_cache[a] = out
    return a, out

# %%
### 표준도로명주소 생성
# 후보 주소 생성(정규화, ‘번지’ 제거, 하이픈 절단, 점진 축약) → 행안부 API 병렬 호출 → 첫 성공값으로 표준도로명주소 채움.

def candidate_sequence(row):
    # 원본 정규화 + '번지' 제거
    raw_road = remove_trailing_bunji(norm_addr(row.get('도로명전체주소')))
    raw_lot  = remove_trailing_bunji(norm_addr(row.get('소재지전체주소')))

    cand = []
    # 도로명 → 소재지 (둘 다 사용)
    for a in [raw_road, raw_lot]:
        if a and a not in cand: cand.append(a)

    # 소재지에서 마지막 '-' 앞까지만
    if raw_lot:
        cut = cut_before_last_dash(raw_lot)
        if cut and cut not in cand and cut != raw_lot:
            cand.append(cut)
        # 소재지 주소 뒤에서 1글자씩 줄이기
        for shr in progressive_shrink(raw_lot):
            if shr not in cand: cand.append(shr)

    return cand

# 표준도로명주소 컬럼 준비 (없으면 생성)
if '표준도로명주소' not in data.columns:
    data['표준도로명주소'] = None

# 표준주소가 비어 있는 행들만 대상 선정
need = data['표준도로명주소'].isna()

# 각 행별 후보열 시퀀스 생성
cseq = data.loc[need].apply(candidate_sequence, axis=1)

# 모든 후보 flatten → 유니크 : 후보 리스트를 평탄화(flatten) 후, 순서를 유지한 중복제거(dict.fromkeys 이용)
all_candidates = []
for lst in cseq: all_candidates.extend(lst)
uniq_candidates = list(dict.fromkeys([a for a in all_candidates if a]))  # 순서유지 dedupe
print("유니크 후보 수:", len(uniq_candidates))

# 병렬 표준화 호출 (후보별 1회)
t0 = time.time()
with ThreadPoolExecutor(max_workers=CONC_JUSO) as ex:
    futures = [ex.submit(juso_standardize, a) for a in uniq_candidates]
    for i, f in enumerate(as_completed(futures), 1):
        if i % 200 == 0 or i == len(futures):
            dt = time.time()-t0
            print(f"[JUSO 호출] {i}/{len(futures)} | {i/max(dt,1):.1f} req/s")

# 행별로 첫 성공값 채워넣기
filled_idx = []
for idx, lst in cseq.items():
    std = None
    for a in lst:
        key = norm_addr(a)
        std = std_cache.get(key) # 캐시에 저장된 표준주소 결과 조회
        if std: break
    if std:
        data.at[idx, '표준도로명주소'] = std
        filled_idx.append(idx)

print(f"이번 라운드 채워짐: {len(filled_idx)}")
print("표준도로명주소 결측:", int(data['표준도로명주소'].isna().sum()), "/", len(data))
# Out:
# 유니크 후보 수: 6724
# [JUSO 호출] 200/6724 | 85.7 req/s
# [JUSO 호출] 400/6724 | 84.9 req/s
# [JUSO 호출] 600/6724 | 85.0 req/s
# [JUSO 호출] 800/6724 | 86.2 req/s
# [JUSO 호출] 1000/6724 | 87.4 req/s
# [JUSO 호출] 1200/6724 | 88.4 req/s
# [JUSO 호출] 1400/6724 | 88.6 req/s
# [JUSO 호출] 1600/6724 | 88.7 req/s
# [JUSO 호출] 1800/6724 | 88.4 req/s
# [JUSO 호출] 2000/6724 | 88.6 req/s
# [JUSO 호출] 2200/6724 | 88.6 req/s
# [JUSO 호출] 2400/6724 | 88.6 req/s
# [JUSO 호출] 2600/6724 | 89.0 req/s
# [JUSO 호출] 2800/6724 | 89.1 req/s
# [JUSO 호출] 3000/6724 | 89.2 req/s
# [JUSO 호출] 3200/6724 | 89.1 req/s
# [JUSO 호출] 3400/6724 | 89.2 req/s
# [JUSO 호출] 3600/6724 | 89.3 req/s
# [JUSO 호출] 3800/6724 | 89.3 req/s
# [JUSO 호출] 4000/6724 | 89.3 req/s
# [JUSO 호출] 4200/6724 | 89.3 req/s
# [JUSO 호출] 4400/6724 | 89.4 req/s
# [JUSO 호출] 4600/6724 | 89.4 req/s
# [JUSO 호출] 4800/6724 | 89.5 req/s
# [JUSO 호출] 5000/6724 | 89.6 req/s
# [JUSO 호출] 5200/6724 | 89.8 req/s
# [JUSO 호출] 5400/6724 | 89.9 req/s
# [JUSO 호출] 5600/6724 | 89.8 req/s
# [JUSO 호출] 5800/6724 | 89.8 req/s
# [JUSO 호출] 6000/6724 | 89.8 req/s
# [JUSO 호출] 6200/6724 | 89.7 req/s
# [JUSO 호출] 6400/6724 | 89.7 req/s
# [JUSO 호출] 6600/6724 | 89.6 req/s
# [JUSO 호출] 6724/6724 | 89.7 req/s
# 이번 라운드 채워짐: 1207
# 표준도로명주소 결측: 0 / 1207

# %%
### 좌표(WGS84) 채우기 → 행정동
# 기존 좌표 (있으면) 5174→WGS84 변환, (없으면) 카카오 주소검색으로 좌표 보강 → 좌표로 행정동/법정동 역지오코딩(캐시+병렬).
# 좌표 있으면 변환 사용
X_COL, Y_COL = '좌표정보x(epsg5174)', '좌표정보y(epsg5174)'
if X_COL not in data.columns: data[X_COL] = None
if Y_COL not in data.columns: data[Y_COL] = None

def try_import_pyproj():
    """
    pyproj(좌표계 변환 라이브러리) 사용 가능 여부 확인.
    - 사용할 수 있으면 5174 → 4326(WGS84) 변환 Transformer 반환
    - 설치/환경 문제 시 None 반환하여 후속 로직이 안전하게 건너뛰도록 함
    """
    try:
        from pyproj import Transformer
        return Transformer.from_crs(5174, 4326, always_xy=True)
    except Exception:
        return None

_transformer = try_import_pyproj()

def tm5174_to_wgs84(x, y):
    """
    EPSG:5174 (TM중부원점) 좌표를 WGS84 경위도(lon, lat)로 변환.
    - 변환기(_transformer)가 없거나 입력이 결측이면 (None, None) 반환
    - 예외 발생 시에도 (None, None)으로 안전하게 처리
    """
    if pd.isna(x) or pd.isna(y) or _transformer is None: return (None, None)
    try:
        lon, lat = _transformer.transform(float(x), float(y))
        return (lon, lat)
    except Exception:
        return (None, None)

# 기존 좌표 → 경위도 변환 적용
xy0 = data[[X_COL, Y_COL]].apply(lambda r: tm5174_to_wgs84(r[X_COL], r[Y_COL]), axis=1)
data['lon'] = [p[0] for p in xy0]
data['lat'] = [p[1] for p in xy0]
print("기존좌표 변환 후 결측(lon/lat):", int((data['lon'].isna()|data['lat'].isna()).sum()))

# 좌표 없는 행만 카카오 주소검색(표준도로명주소로)
addr_cache, addr_lock = {}, threading.Lock()
def kakao_geocode(addr: str):
    """
    카카오 주소검색 API로 주소 → (x=lon, y=lat) 좌표를 획득
    - 내부 캐시(addr_cache)와 락으로 중복호출/경쟁상황 방지
    - 재시도 및 backoff 적용
    """
    if not isinstance(addr, str) or not addr.strip(): return (None, None)
    a = norm_addr(addr)
    with addr_lock:
        if a in addr_cache: return addr_cache[a]
    out = (None, None)
    for attempt in range(1, MAX_RETRY+2):
        try:
            r = requests.get(ADDR_URL, headers=HEADERS, params={"query": a}, timeout=TIMEOUT)
            r.raise_for_status()
            docs = r.json().get("documents", [])
            out = (float(docs[0]['x']), float(docs[0]['y'])) if docs else (None, None)
            break
        except Exception:
            if attempt == MAX_RETRY+1: out = (None, None)
            else: time.sleep(0.4*attempt)
    with addr_lock:
        addr_cache[a] = out
    return out

# lon/lat 결측인 행만 대상으로 고유 표준주소 목록을 생성하여 병렬 지오코딩
need_geo = data['lon'].isna() | data['lat'].isna()
uniq_std = data.loc[need_geo, '표준도로명주소'].dropna().unique().tolist()

t2 = time.time()
with ThreadPoolExecutor(max_workers=CONC_KAKAO) as ex:
    futures = [ex.submit(kakao_geocode, a) for a in uniq_std]
    for i, f in enumerate(as_completed(futures), 1):
        if i % 200 == 0 or i == len(futures):
            dt = time.time()-t2
            print(f"[카카오 지오코딩] {i}/{len(uniq_std)} | {i/max(dt,1):.1f} req/s")

# 지오코딩 결과를 행 단위로 매핑하여 lon/lat 채우기
data.loc[need_geo, 'lon'] = data.loc[need_geo, '표준도로명주소'].map(
    lambda a: addr_cache.get(norm_addr(a),(None,None))[0]
).astype('float64').values
data.loc[need_geo, 'lat'] = data.loc[need_geo, '표준도로명주소'].map(
    lambda a: addr_cache.get(norm_addr(a),(None,None))[1]
).astype('float64').values
print("최종 좌표 결측:", int((data['lon'].isna() | data['lat'].isna()).sum()))

# 좌표 -> 행정동/법정동
rc_cache, rc_lock = {}, threading.Lock()
def coord2region(lon, lat):
    """
    카카오 coord2regioncode API를 사용해 좌표 → 행정동/법정동 메타데이터를 조회
    - region_type 'H' (행정동), 'B' (법정동) 각각의 3단계 이름 및 코드 반환
    - 네트워크 오류 시 재시도, 그래도 실패하면 None 필드 유지
    """
    if pd.isna(lon) or pd.isna(lat):
        return {"행정동":None,"행정동코드":None,"법정동명":None,"법정동코드":None}
    key = (float(lon), float(lat))
    with rc_lock:
        if key in rc_cache: return rc_cache[key]
    out = {"행정동":None,"행정동코드":None,"법정동명":None,"법정동코드":None}
    for attempt in range(1, MAX_RETRY+2):
        try:
            r = requests.get(REGION_URL, headers=HEADERS, params={"x": key[0], "y": key[1]}, timeout=TIMEOUT)
            r.raise_for_status()
            docs = r.json().get("documents", [])
            h = next((d for d in docs if d.get('region_type')=='H'), None)
            b = next((d for d in docs if d.get('region_type')=='B'), None)
            out = {
                "행정동": (h or {}).get("region_3depth_name"),
                "행정동코드": (h or {}).get("code"),
                "법정동명": (b or {}).get("region_3depth_name"),
                "법정동코드": (b or {}).get("code"),
            }
            break
        except Exception:
            if attempt == MAX_RETRY+1: pass
            else: time.sleep(0.4*attempt)
    with rc_lock:
        rc_cache[key] = out
    return out

# 중복 좌표에 대한 API 호출을 줄이기 위해 고유 (lon, lat) 페어에 대해서만 병렬 조회
pairs = pd.Series(list(zip(data['lon'], data['lat']))).dropna().unique().tolist()
t3 = time.time()
with ThreadPoolExecutor(max_workers=CONC_KAKAO) as ex:
    futures = [ex.submit(coord2region, *p) for p in pairs]
    for i, f in enumerate(as_completed(futures), 1):
        if i % 300 == 0 or i == len(futures):
            dt = time.time()-t3
            print(f"[행정동 조회] {i}/{len(pairs)} | {i/max(dt,1):.1f} req/s")

# 조회 결과를 기존 데이터프레임 순서에 맞춰 병합
tmp = data[['lon','lat']].apply(lambda r: rc_cache.get((r['lon'], r['lat']),
                    {"행정동":None,"행정동코드":None,"법정동명":None,"법정동코드":None}), axis=1)
tmp = pd.json_normalize(tmp)
data[['행정동','행정동코드','법정동명','법정동코드']] = tmp[['행정동','행정동코드','법정동명','법정동코드']].values

print("총 건수:", len(data), " | 행정동 결측:", int(data['행정동'].isna().sum()))
data[['소재지전체주소','도로명전체주소','표준도로명주소','lon','lat','행정동']].head(10)
# Out:
# 기존좌표 변환 후 결측(lon/lat): 15
# [카카오 지오코딩] 15/15 | 15.0 req/s
# 최종 좌표 결측: 0
# [행정동 조회] 300/1136 | 154.3 req/s
# [행정동 조회] 600/1136 | 152.8 req/s
# [행정동 조회] 900/1136 | 151.5 req/s
# [행정동 조회] 1136/1136 | 125.1 req/s
# 총 건수: 1207  | 행정동 결측: 0
#                   소재지전체주소               도로명전체주소                     표준도로명주소  \
# 0   서울특별시 종로구 원남동 49-17번지     서울특별시 종로구 율곡로 180     서울특별시 종로구 율곡로 180 (원남동)
# 1    서울특별시 종로구 창신동 328-18      서울특별시 종로구 지봉로 19      서울특별시 종로구 지봉로 19 (창신동)
# 2   서울특별시 종로구 통인동 147-4번지   서울특별시 종로구 자하문로 35-6   서울특별시 종로구 자하문로 35-6 (통인동)
# 3     서울특별시 종로구 창신동 578-1      서울특별시 종로구 창신길 22      서울특별시 종로구 창신길 22 (창신동)
# 4    서울특별시 종로구 관훈동 197-28    서울특별시 종로구 인사동7길 12    서울특별시 종로구 인사동7길 12 (관훈동)
# 5      서울특별시 종로구 숭인동 55-6      서울특별시 종로구 지봉로 82      서울특별시 종로구 지봉로 82 (숭인동)
# 6     서울특별시 종로구 통인동 35-16    서울특별시 종로구 필운대로6길 3    서울특별시 종로구 필운대로6길 3 (통인동)
# 7    서울특별시 종로구 삼일대로30길 31  서울특별시 종로구 삼일대로30길 31  서울특별시 종로구 삼일대로30길 31 (익선동)
# 8  서울특별시 종로구 명륜1가 10-16번지       서울특별시 종로구 명륜길 8      서울특별시 종로구 명륜길 8 (명륜1가)
# 9   서울특별시 종로구 적선동 122-1번지  서울특별시 종로구 새문안로5가길 32  서울특별시 종로구 새문안로5가길 32 (적선동)
#
#           lon        lat          행정동
# 0  126.998766  37.575725  종로1.2.3.4가동
# 1  127.015208  37.571758         창신1동
# 2  126.970922  37.579146        청운효자동
# 3  127.011022  37.572620         창신2동
# 4  126.985212  37.573087  종로1.2.3.4가동
# 5  127.015686  37.577449         숭인1동
# 6  126.968844  37.580902        청운효자동
# 7  126.989462  37.574417  종로1.2.3.4가동
# 8  126.996367  37.588129          혜화동
# 9  126.973431  37.574912          사직동

# %%
data
# Out:
#      개방서비스명 상세영업상태명       폐업일자    소재지면적                 소재지전체주소  \
# 0      목욕장업      영업        NaT   233.95   서울특별시 종로구 원남동 49-17번지
# 1      목욕장업      영업        NaT  2089.91    서울특별시 종로구 창신동 328-18
# 2      목욕장업      영업        NaT   262.26   서울특별시 종로구 통인동 147-4번지
# 3      목욕장업      영업        NaT   249.10     서울특별시 종로구 창신동 578-1
# 4      목욕장업      영업        NaT  1430.00    서울특별시 종로구 관훈동 197-28
# ...     ...     ...        ...      ...                     ...
# 3896   목욕장업      폐업 2020-11-16  1980.00   서울특별시 강동구 천호동 410-105
# 3911   목욕장업      폐업 2018-09-27   161.16  서울특별시 강동구 암사동 421-23번지
# 3912   목욕장업      폐업 2017-02-23   349.67  서울특별시 강동구 암사동 514-55번지
# 3941   목욕장업      폐업 2022-06-13   822.98     서울특별시 강동구 성내동 549-4
# 3949   목욕장업      폐업 2019-03-07   198.00  서울특별시 강동구 성내동 127-25번지
#
#                    도로명전체주소         사업장명  좌표정보x(epsg5174)  좌표정보y(epsg5174)  \
# 0        서울특별시 종로구 율곡로 180  오라카이 대학로 호텔    199821.363678    452603.475535
# 1         서울특별시 종로구 지봉로 19         스파렉스    201273.887782    452163.292543
# 2      서울특별시 종로구 자하문로 35-6          인왕탕    197361.848626    452983.593504
# 3         서울특별시 종로구 창신길 22       현대옥사우나    200904.097307    452258.945718
# 4       서울특별시 종로구 인사동7길 12        백상대중탕    198624.006469    452310.752961
# ...                    ...          ...              ...              ...
# 3896     서울특별시 강동구 진황도로 18      현대비전사우나    211336.172452    448556.794492
# 3911  서울특별시 강동구 구천면로 371-5           상원    212306.755356    449855.853977
# 3912    서울특별시 강동구 상암로4길 52           남양              NaN              NaN
# 3941      서울특별시 강동구 성내로 52          퍼시픽    211039.290221    447345.670673
# 3949    서울특별시 강동구 천호옛8길 11        성일목욕탕    210899.162873    447909.072217
#
#       욕실수  ... 여성종사자수  남성종사자수  다중이용업소여부                     표준도로명주소  \
# 0     0.0  ...    0.0     0.0         N     서울특별시 종로구 율곡로 180 (원남동)
# 1     8.0  ...    0.0     0.0         N      서울특별시 종로구 지봉로 19 (창신동)
# 2     NaN  ...    NaN     NaN         N   서울특별시 종로구 자하문로 35-6 (통인동)
# 3     0.0  ...    0.0     0.0         N      서울특별시 종로구 창신길 22 (창신동)
# 4     NaN  ...    NaN     NaN         N    서울특별시 종로구 인사동7길 12 (관훈동)
# ...   ...  ...    ...     ...       ...                         ...
# 3896  2.0  ...    NaN     NaN         N    서울특별시 강동구 진황도로 5-1 (천호동)
# 3911  2.0  ...    NaN     NaN         N  서울특별시 강동구 구천면로 371-5 (암사동)
# 3912  2.0  ...    NaN     NaN         N    서울특별시 강동구 암사13길 19 (암사동)
# 3941  2.0  ...    0.0     0.0         N      서울특별시 강동구 성내로 52 (성내동)
# 3949  6.0  ...    0.0     0.0         N    서울특별시 강동구 천호옛8길 11 (성내동)
#
#              lon        lat          행정동       행정동코드 법정동명       법정동코드
# 0     126.998766  37.575725  종로1.2.3.4가동  1111061500  원남동  1111015900
# 1     127.015208  37.571758         창신1동  1111067000  창신동  1111017400
# 2     126.970922  37.579146        청운효자동  1111051500  통인동  1111010800
# 3     127.011022  37.572620         창신2동  1111068000  창신동  1111017400
# 4     126.985212  37.573087  종로1.2.3.4가동  1111061500  관훈동  1111012800
# ...          ...        ...          ...         ...  ...         ...
# 3896  127.129055  37.539196         천호3동  1174062000  천호동  1174010900
# 3911  127.140058  37.550888         암사1동  1174057000  암사동  1174010700
# 3912  127.136971  37.552908         암사1동  1174057000  암사동  1174010700
# 3941  127.125677  37.528287         성내1동  1174064000  성내동  1174010800
# 3949  127.124100  37.533365         성내2동  1174065000  성내동  1174010800
#
# [1207 rows x 21 columns]

# %%
data.columns
# Out:
# Index(['개방서비스명', '상세영업상태명', '폐업일자', '소재지면적', '소재지전체주소', '도로명전체주소', '사업장명',
#        '좌표정보x(epsg5174)', '좌표정보y(epsg5174)', '욕실수', '발한실여부', '여성종사자수',
#        '남성종사자수', '다중이용업소여부', '표준도로명주소', 'lon', 'lat', '행정동', '행정동코드', '법정동명',
#        '법정동코드'],
#       dtype='object')

# %%
data[data['행정동'].isna() == 1]
# Out:
# Empty DataFrame
# Columns: [개방서비스명, 상세영업상태명, 폐업일자, 소재지면적, 소재지전체주소, 도로명전체주소, 사업장명, 좌표정보x(epsg5174), 좌표정보y(epsg5174), 욕실수, 발한실여부, 여성종사자수, 남성종사자수, 다중이용업소여부, 표준도로명주소, lon, lat, 행정동, 행정동코드, 법정동명, 법정동코드]
# Index: []
#
# [0 rows x 21 columns]

# %%
data[data['표준도로명주소'].isna() == 1]
# Out:
# Empty DataFrame
# Columns: [개방서비스명, 상세영업상태명, 폐업일자, 소재지면적, 소재지전체주소, 도로명전체주소, 사업장명, 좌표정보x(epsg5174), 좌표정보y(epsg5174), 욕실수, 발한실여부, 여성종사자수, 남성종사자수, 다중이용업소여부, 표준도로명주소, lon, lat, 행정동, 행정동코드, 법정동명, 법정동코드]
# Index: []
#
# [0 rows x 21 columns]

# %%
data.columns
# Out:
# Index(['개방서비스명', '상세영업상태명', '폐업일자', '소재지면적', '소재지전체주소', '도로명전체주소', '사업장명',
#        '좌표정보x(epsg5174)', '좌표정보y(epsg5174)', '욕실수', '발한실여부', '여성종사자수',
#        '남성종사자수', '다중이용업소여부', '표준도로명주소', 'lon', 'lat', '행정동', '행정동코드', '법정동명',
#        '법정동코드'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1207 entries, 0 to 3949
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   개방서비스명           1207 non-null   object
#  1   상세영업상태명          1207 non-null   object
#  2   폐업일자             542 non-null    datetime64[ns]
#  3   소재지면적            1207 non-null   float64
#  4   소재지전체주소          1207 non-null   object
#  5   도로명전체주소          1207 non-null   object
#  6   사업장명             1207 non-null   object
#  7   좌표정보x(epsg5174)  1192 non-null   float64
#  8   좌표정보y(epsg5174)  1192 non-null   float64
#  9   욕실수              1049 non-null   float64
#  10  발한실여부            1207 non-null   object
#  11  여성종사자수           661 non-null    float64
#  12  남성종사자수           661 non-null    float64
#  13  다중이용업소여부         1207 non-null   object
#  14  표준도로명주소          1207 non-null   object
#  15  lon              1207 non-null   float64
#  16  lat              1207 non-null   float64
#  17  행정동              1207 non-null   object
#  18  행정동코드            1207 non-null   object
#  19  법정동명             1207 non-null   object
#  20  법정동코드            1207 non-null   object
# dtypes: datetime64[ns](1), float64(8), object(12)
# memory usage: 239.7+ KB

# %%
## 일단 행정동 추출까지 된 데이터 저장
data.to_csv('../data/processed/인허가_목욕장업_행정동추출.csv', index=False, encoding='utf-8-sig')

# %%
### 행정동 기반 목용장업 데이터에 물재생센터 정보 병합 ###
# 먼저 '행정동' 이름 기준으로 병합 시도 (validate="m:1" 안전장치)
# 만약 매핑에서 H_DNG_NM 중복 때문에 실패하거나 안전하지 않으면,
#    - 중복이지만 처리센터가 모두 동일하면 안전 축약 후 이름 기준 병합
#    - 그게 아니면 "코드 기준 폴백":
#       df: 행정동명 정정(신설/용두→용신, 면목제3.8→면목3.8)
#       df: 행정동코드_trim = 행정동코드 // 100 (뒤 '00' 제거)
#       mapping: 행정동코드는 이미 8자리(trim) → 숫자형 변환만
#       df에서 '용신동'인 행의 행정동코드_trim을 매핑의 용신동 코드로 덮어쓰기
#       df['행정동코드_trim'] ↔ mapping['행정동코드'] 로 left join


df = pd.read_csv('../data/processed/인허가_목욕장업_행정동추출.csv', encoding='utf-8-sig')
mapping_df = pd.read_excel('../data/raw/행정동16년 기준 매핑.xlsx', engine='openpyxl')


# 행정동명 정정
# 신설동, 용두동 -> 용신동
# 면목제3.8동 -> 면목3.8동
name_fix = {'신설동': '용신동', 
            '용두동': '용신동', 
            '면목제3.8동': '면목3.8동'}
df['행정동'] = df['행정동'].replace(name_fix)

# '행정동' 컬럼 기반 병합 우선 시도 
def try_merge_by_name(df_in, map_in):
    """
    H_DNG_NM이 유일하면 이름 기준 병합을 시도하고 결과를 반환.
    유일하지 않다면 None을 반환.
    """
    if map_in['H_DNG_NM'].duplicated().any():
        return None  # 유일하지 않음 → 폴백 필요

    # 병합 (행정동 이름 기준)
    merged_name = df_in.merge(
        map_in[['H_DNG_NM', '처리센터']],
        how='left',
        left_on='행정동',
        right_on='H_DNG_NM',
        validate='m:1'  # 왼쪽 many, 오른쪽 one
    ).rename(columns={'처리센터':'물재생센터'}).drop(columns=['H_DNG_NM'])
    return merged_name

# 일단 시도
merged = try_merge_by_name(df, mapping_df)

# 이름 중복이 있다면: 중복 안전 축약 or 코드 폴백
if merged is None:
    # 중복 진단: 같은 동 이름에 서로 다른 처리센터가 있는지 확인
    g = mapping_df.groupby('H_DNG_NM')['처리센터'].nunique().reset_index(name='센터_고유값_수')
    conflict_keys = g.loc[g['센터_고유값_수'] > 1, 'H_DNG_NM'].tolist()

    if len(conflict_keys) == 0:
        # 처리센터가 실제로는 동일 → 완전 중복(동일 동+센터)이라면 안전 축약 가능
        map_dedup_safe = mapping_df.drop_duplicates(subset=['H_DNG_NM', '처리센터'], keep='first')
        # 여전히 H_DNG_NM 중복이 남는지 확인
        if map_dedup_safe['H_DNG_NM'].duplicated().any():
            # 이론상 거의 없지만, 혹시 남아있으면 코드 폴백으로 전환
            need_fallback = True
        else:
            need_fallback = False
            merged = try_merge_by_name(df, map_dedup_safe)
    else:
        # 같은 동 이름에 처리센터가 서로 다름 → 이름만으론 모호 → 코드 폴백
        need_fallback = True

    # 코드 폴백 (필요한 경우만)
    if merged is None and need_fallback:
        # df 쪽 코드 정규화: 뒤 2자리 제거한 8자리 trim 생성 <- 매핑 데이터의 행정동코드가 이미 8자리로 되어 있기때문에 필요
        df['행정동코드'] = pd.to_numeric(df['행정동코드'], errors='coerce').astype('Int64')
        df['행정동코드_trim'] = (df['행정동코드'] // 100).astype('Int64')

        # mapping 쪽은 이미 8자리 → 숫자형만 보정
        mapping_df['행정동코드'] = pd.to_numeric(mapping_df['행정동코드'], errors='coerce').astype('Int64')

        # 용신동 코드(8자리) 추출
        ys_code = mapping_df.loc[mapping_df['H_DNG_NM'] == '용신동', '행정동코드']
        if ys_code.empty:
            raise ValueError("매핑 파일에서 '용신동'의 행정동코드를 찾지 못했습니다.")
        ys_code = ys_code.iloc[0]

        # df에서 '용신동'으로 정정된 모든 행에 용신동 코드 적용
        df.loc[df['행정동'].eq('용신동'), '행정동코드_trim'] = ys_code

        # 코드 기준 병합
        merged = df.merge(
            mapping_df[['행정동코드', '처리센터']].drop_duplicates(subset=['행정동코드']),
            how='left',
            left_on='행정동코드_trim',
            right_on='행정동코드'
        ).rename(columns={'처리센터':'물재생센터'})

print(f"[요약] 전체 행: {len(merged):,d}")
print(f"[요약] 매핑 성공: {(~merged['물재생센터'].isna()).sum():,d}")
print(f"[요약] 매핑 실패: {merged['물재생센터'].isna().sum():,d}")

merged.to_csv('../data/processed/인허가_목욕장업_물재생센터매핑_결과.csv',
              index=False, encoding='utf-8-sig')
print("[저장 완료] ../data/processed/인허가_목욕장업_물재생센터매핑_결과.csv")
# Out:
# [요약] 전체 행: 1,207
# [요약] 매핑 성공: 1,207
# [요약] 매핑 실패: 0
# [저장 완료] ../data/processed/인허가_목욕장업_물재생센터매핑_결과.csv

# %%
merged.columns
# Out:
# Index(['개방서비스명', '상세영업상태명', '폐업일자', '소재지면적', '소재지전체주소', '도로명전체주소', '사업장명',
#        '좌표정보x(epsg5174)', '좌표정보y(epsg5174)', '욕실수', '발한실여부', '여성종사자수',
#        '남성종사자수', '다중이용업소여부', '표준도로명주소', 'lon', 'lat', '행정동', '행정동코드', '법정동명',
#        '법정동코드', '물재생센터'],
#       dtype='object')

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1207 entries, 0 to 1206
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   개방서비스명           1207 non-null   object
#  1   상세영업상태명          1207 non-null   object
#  2   폐업일자             542 non-null    object
#  3   소재지면적            1207 non-null   float64
#  4   소재지전체주소          1207 non-null   object
#  5   도로명전체주소          1207 non-null   object
#  6   사업장명             1207 non-null   object
#  7   좌표정보x(epsg5174)  1192 non-null   float64
#  8   좌표정보y(epsg5174)  1192 non-null   float64
#  9   욕실수              1049 non-null   float64
#  10  발한실여부            1207 non-null   object
#  11  여성종사자수           661 non-null    float64
#  12  남성종사자수           661 non-null    float64
#  13  다중이용업소여부         1207 non-null   object
#  14  표준도로명주소          1207 non-null   object
#  15  lon              1207 non-null   float64
#  16  lat              1207 non-null   float64
#  17  행정동              1207 non-null   object
#  18  행정동코드            1207 non-null   int64
#  19  법정동명             1207 non-null   object
#  20  법정동코드            1207 non-null   int64
#  21  물재생센터            1207 non-null   object
# dtypes: float64(8), int64(2), object(12)
# memory usage: 207.6+ KB

# %%
# 결측은 NaN 유지, 나머지만 int 변환
merged['여성종사자수'] = merged['여성종사자수'].astype('Int64')
merged['남성종사자수'] = merged['남성종사자수'].astype('Int64')
merged['욕실수'] = merged['욕실수'].astype('Int64')

# %%
merged['소재지면적'].value_counts() # 0인 값이 4개 있는데 그냥 제거하는게 나을듯함 전체 비율의 0.33% 정도임
# Out:
# 소재지면적
# 660.00    9
# 198.00    6
# 264.00    5
# 0.00      4
# 330.00    4
#          ..
# 183.00    1
# 11.50     1
# 8.50      1
# 184.80    1
# 822.98    1
# Name: count, Length: 1124, dtype: int64

# %%
merged = merged[merged['소재지면적'] != 0] # 소재지면적이 0인값 제거
merged['소재지면적'].value_counts()
# Out:
# 소재지면적
# 660.00    9
# 198.00    6
# 264.00    5
# 330.00    4
# 825.00    4
#          ..
# 183.00    1
# 11.50     1
# 8.50      1
# 184.80    1
# 196.56    1
# Name: count, Length: 1123, dtype: int64

# %%
merged['욕실수'].value_counts() # 0인값이 너무 많음
# Out:
# 욕실수
# 0     417
# 2     378
# 1      96
# 3      35
# 6      31
# 4      29
# 8      17
# 5      17
# 10      7
# 9       5
# 7       4
# 12      3
# 14      2
# 11      2
# 16      2
# 17      1
# Name: count, dtype: Int64

# %%
missing_bath = merged[merged['욕실수'].isna()]
print("욕실수 결측 행 수:", len(missing_bath))
missing_bath[['폐업일자', '소재지면적', '욕실수', '발한실여부', '표준도로명주소', '물재생센터']].head(10)
# Out:
# 욕실수 결측 행 수: 157
#    폐업일자    소재지면적   욕실수 발한실여부                             표준도로명주소    물재생센터
# 2   NaN   262.26  <NA>     N           서울특별시 종로구 자하문로 35-6 (통인동)  중랑물재생센터
# 4   NaN  1430.00  <NA>     N            서울특별시 종로구 인사동7길 12 (관훈동)  중랑물재생센터
# 6   NaN   480.00  <NA>     N            서울특별시 종로구 필운대로6길 3 (통인동)  중랑물재생센터
# 8   NaN   468.27  <NA>     N              서울특별시 종로구 명륜길 8 (명륜1가)  중랑물재생센터
# 9   NaN   598.44  <NA>     N          서울특별시 종로구 새문안로5가길 32 (적선동)  중랑물재생센터
# 11  NaN   949.46  <NA>     N  서울특별시 종로구 삼일대로30길 21 (낙원동, 종로오피스텔)  중랑물재생센터
# 15  NaN   432.00  <NA>     N           서울특별시 종로구 새문안로3길 30 (내수동)  중랑물재생센터
# 16  NaN   912.97  <NA>     N             서울특별시 종로구 진흥로 432 (구기동)  난지물재생센터
# 17  NaN  1243.48  <NA>     N          서울특별시 종로구 창경궁로 112-7 (인의동)  중랑물재생센터
# 18  NaN   625.94  <NA>     N    서울특별시 종로구 율곡로6길 36 (운니동, 오피스텔월드)  중랑물재생센터

# %%
merged['여성종사자수'].value_counts() # 0인값이 너무 많음
# Out:
# 여성종사자수
# 0     635
# 1       9
# 2       8
# 4       3
# 20      2
# 5       2
# 10      1
# 11      1
# Name: count, dtype: Int64

# %%
### '욕실수','여성종사자수', '남성종사자수' 컬럼 제거 : 결측치 채울 수 없음
merged = merged.drop(['욕실수','여성종사자수', '남성종사자수'], axis=1)
merged.columns
# Out:
# Index(['개방서비스명', '상세영업상태명', '폐업일자', '소재지면적', '소재지전체주소', '도로명전체주소', '사업장명',
#        '좌표정보x(epsg5174)', '좌표정보y(epsg5174)', '발한실여부', '다중이용업소여부', '표준도로명주소',
#        'lon', 'lat', '행정동', '행정동코드', '법정동명', '법정동코드', '물재생센터'],
#       dtype='object')

# %%
### 전처리에 사용하였으나, 더이상 필요없는 컬럼 제거
merged = merged.drop(['상세영업상태명', '소재지전체주소', '도로명전체주소', '사업장명',
       '좌표정보x(epsg5174)', '좌표정보y(epsg5174)','표준도로명주소',
       'lon', 'lat', '행정동', '행정동코드', '법정동명', '법정동코드'], axis=1)

merged
# Out:
#      개방서비스명        폐업일자    소재지면적 발한실여부 다중이용업소여부    물재생센터
# 0      목욕장업         NaN   233.95     N        N  중랑물재생센터
# 1      목욕장업         NaN  2089.91     Y        N  중랑물재생센터
# 2      목욕장업         NaN   262.26     N        N  중랑물재생센터
# 3      목욕장업         NaN   249.10     N        N  중랑물재생센터
# 4      목욕장업         NaN  1430.00     N        N  중랑물재생센터
# ...     ...         ...      ...   ...      ...      ...
# 1202   목욕장업  2020-11-16  1980.00     Y        N  탄천물재생센터
# 1203   목욕장업  2018-09-27   161.16     Y        N  탄천물재생센터
# 1204   목욕장업  2017-02-23   349.67     Y        N  탄천물재생센터
# 1205   목욕장업  2022-06-13   822.98     Y        N  탄천물재생센터
# 1206   목욕장업  2019-03-07   198.00     N        N  탄천물재생센터
#
# [1203 rows x 6 columns]

# %%
merged.to_csv('../data/processed/인허가_목욕장업_일자별정리_준비.csv', encoding='utf-8-sig', index=False)

# %%
src_path = "../data/processed/인허가_목욕장업_일자별정리_준비.csv"
df = pd.read_csv(src_path, encoding="utf-8-sig")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1203 entries, 0 to 1202
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   개방서비스명    1203 non-null   object
#  1   폐업일자      540 non-null    object
#  2   소재지면적     1203 non-null   float64
#  3   발한실여부     1203 non-null   object
#  4   다중이용업소여부  1203 non-null   object
#  5   물재생센터     1203 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 56.5+ KB

# %%
# 2017-01-01 ~ 2025-06-30 기간에 대해 물재생센터 4개 × 매일 1행으로 구성된 일자별 데이터
"""
2017-01-01 ~ 2025-06-30 기간에 대해
물재생센터 4개 x 매일 1행이 존재하는 일자별 데이터를 생성

- 개업일자 정보 없음 → 모든 시설은 2017-01-01부터 존재한다고 가정
- 폐업일자 존재 시 → 폐업일 '전날'까지 영업(폐업일 당일은 영업 X)
- 날짜×센터의 모든 조합을 '풀그리드'로 만든 뒤, 누락은 0/기본값으로 채움

입출력
- 입력:  ../data/processed/인허가_목욕장업_일자별정리_준비.csv
- 출력:  ../data/processed/인허가_목욕장업_일자별_물재생센터_영업현황_20170101_20250630.csv
"""

import pandas as pd
import numpy as np
from itertools import product

# 기간 설정
START = pd.Timestamp("2017-01-01")
END = pd.Timestamp("2025-06-30")

# 날짜×센터 풀그리드 생성 시 사용할 '일 단위' 날짜 인덱스
date_index = pd.date_range(START, END, freq="D")

src_path = "../data/processed/인허가_목욕장업_일자별정리_준비.csv"
df = pd.read_csv(src_path, encoding="utf-8-sig")

# 수치형 변환: 면적은 숫자형으로 통일 (문자 → NaN 허용)
df["소재지면적"] = pd.to_numeric(df["소재지면적"], errors="coerce")
# 날짜형 변환: 문자열 → datetime (변환 불가/빈 값은 NaT)
df["폐업일자"] = pd.to_datetime(df["폐업일자"], errors="coerce")

# 물재생센터 목록 추출 (요구사항: 최종적으로 날짜마다 센터 4개 행이 나와야 함)
centers = df["물재생센터"].unique().tolist()

# 영업 기간 계산 : 개업일자 정보가 없으므로 모든 시설이 START부터 존재한다고 가정
df["영업시작일"] = START

# 폐업일자가 있으면 폐업일 전날까지 영업으로 간주
#  - 예: 폐업일=2020-01-10 → 영업종료일_포함 = 2020-01-09
df["영업종료일_포함"] = df["폐업일자"] - pd.Timedelta(days=1)
# 폐업일자 NaT(=미폐업)인 시설은 END까지 영업한다고 간주
df["영업종료일_포함"] = df["영업종료일_포함"].fillna(END)
# 영업 종료일이 분석 종료일을 넘어가면 END로 클리핑
df["영업종료일_포함"] = df["영업종료일_포함"].where(df["영업종료일_포함"] <= END, END)
# 종료일 < 시작일인 레코드는 분석 기간과 겹치지 않으므로 제거
df = df[df["영업종료일_포함"] >= df["영업시작일"]].copy()

# 시설 단위 → 일자 단위 확장 
# 각 시설 레코드마다 [영업시작일, 영업종료일_포함] 구간의 모든 날짜를 생성하여
# 시설 속성(면적, 발한실여부, 다중이용업소여부 등)을 일자별로 복제
def make_daily_rows(row):
    # 시설의 실제 운영 기간과 분석 기간이 겹치는 부분만 날짜 생성
    dts = pd.date_range(max(row["영업시작일"], START),
                        min(row["영업종료일_포함"], END),
                        freq="D")
    if len(dts) == 0:
        # 겹치는 날짜가 전혀 없을 경우 빈 프레임 반환
        return pd.DataFrame(columns=[
            "date", "물재생센터", "개방서비스명",
            "소재지면적", "발한실여부", "다중이용업소여부", "시설_운영"
        ])
    # 운영 중인 기간의 각 날짜별 행 생성
    return pd.DataFrame({
        "date": dts,
        "물재생센터": row["물재생센터"],
        "개방서비스명": row["개방서비스명"],
        "소재지면적": row["소재지면적"],
        "발한실여부": row["발한실여부"],
        "다중이용업소여부": row["다중이용업소여부"],
        # 이후 집계에서 '운영 시설 수'를 계산하기 위해
        "시설_운영": 1
    })

# 모든 시설 레코드에 대해 일자 단위로 확장
daily_list = [make_daily_rows(r) for _, r in df.iterrows()]

# 빈 리스트 방지: concat 전에 조건 처리
fac_daily = (
    pd.concat(daily_list, ignore_index=True)
    if len(daily_list) > 0 else
    pd.DataFrame(columns=[
        "date", "물재생센터", "개방서비스명",
        "소재지면적", "발한실여부", "다중이용업소여부", "시설_운영"
    ])
)

# 날짜×센터 집계
# 동일한 날짜/센터 내에서 여러 시설(행)이 존재할 수 있으므로
#  - 시설수_운영: 해당 일자에 운영 중인 시설 수 (시설_운영 합)
#  - 총소재지면적_운영: 운영 시설들의 면적 합
#  - 발한실_운영: 운영 시설 중 발한실여부 == "Y" 개수
#  - 다중이용_운영: 운영 시설 중 다중이용업소여부 == "Y" 개수
# 이후 시설수_운영 > 0이면 영업여부_센터 = 1, 아니면 0
if not fac_daily.empty:
    grp = fac_daily.groupby(["date", "물재생센터"], as_index=False).agg(
        시설수_운영=("시설_운영", "sum"),
        총소재지면적_운영=("소재지면적", "sum"),
        발한실_운영=("발한실여부", lambda s: (s == "Y").sum()),
        다중이용_운영=("다중이용업소여부", lambda s: (s == "Y").sum()),
    )
    grp["영업여부_센터"] = (grp["시설수_운영"] > 0).astype(int)

    # 개방서비스명
    mode_by_center = (
        fac_daily.groupby("물재생센터")["개방서비스명"]
        .agg(lambda s: s.mode().iat[0] if not s.mode().empty else s.iloc[0])
    )
    grp = grp.merge(mode_by_center.rename("개방서비스명"), on="물재생센터", how="left")
else:
    # 예외 처리 : 확장 결과가 비었을 때의 스키마 유지
    grp = pd.DataFrame(columns=[
        "date", "물재생센터", "시설수_운영", "총소재지면적_운영",
        "발한실_운영", "다중이용_운영", "영업여부_센터", "개방서비스명"
    ])

# 날짜×센터 풀그리드 결합
# 모든 날짜(date_index) × 모든 센터(centers) 조합을 만든 뒤,
# 위 집계(grp)를 LEFT JOIN → 누락된 조합은 0/기본값으로 채움
full_grid = pd.DataFrame(list(product(date_index, centers)), columns=["date", "물재생센터"])
daily_center = full_grid.merge(grp, on=["date", "물재생센터"], how="left")

# 결측치 처리 규칙:
#  - 운영 관련 수치(시설수_운영, 총소재지면적_운영, 발한실_운영, 다중이용_운영, 영업여부_센터) → 0
#  - 개방서비스명 → 센터별/전체 최빈값(없으면 '목욕장업')
default_service = (
    fac_daily["개방서비스명"].mode().iat[0]
    if not fac_daily.empty and not fac_daily["개방서비스명"].mode().empty
    else "목욕장업"
)
for col in ["시설수_운영", "총소재지면적_운영", "발한실_운영", "다중이용_운영", "영업여부_센터"]:
    daily_center[col] = daily_center[col].fillna(0)
daily_center["개방서비스명"] = daily_center["개방서비스명"].fillna(default_service)

# 최종 컬럼 순서로 정리하고, 날짜/센터 기준 오름차순 정렬
daily_center = daily_center[[
    "date", "물재생센터", "개방서비스명",
    "영업여부_센터", "시설수_운영", "총소재지면적_운영",
    "발한실_운영", "다중이용_운영"
]].sort_values(["date", "물재생센터"], ignore_index=True)

out_path = "../data/processed/인허가_목욕장업_일자별_물재생센터_영업현황_20170101_20250630.csv"
daily_center.to_csv(out_path, index=False, encoding="utf-8-sig")

print(f"[저장 완료] {out_path}")
daily_center.head(10)
# Out:
# [저장 완료] ../data/processed/인허가_목욕장업_일자별_물재생센터_영업현황_20170101_20250630.csv
#         date    물재생센터 개방서비스명  영업여부_센터  시설수_운영  총소재지면적_운영  발한실_운영  다중이용_운영
# 0 2017-01-01  난지물재생센터   목욕장업        1     207  139616.41      91        3
# 1 2017-01-01  서남물재생센터   목욕장업        1     455  630651.35     199       54
# 2 2017-01-01  중랑물재생센터   목욕장업        1     352  284426.11      85       20
# 3 2017-01-01  탄천물재생센터   목욕장업        1     189  136330.94      63       19
# 4 2017-01-02  난지물재생센터   목욕장업        1     207  139616.41      91        3
# 5 2017-01-02  서남물재생센터   목욕장업        1     455  630651.35     199       54
# 6 2017-01-02  중랑물재생센터   목욕장업        1     352  284426.11      85       20
# 7 2017-01-02  탄천물재생센터   목욕장업        1     189  136330.94      63       19
# 8 2017-01-03  난지물재생센터   목욕장업        1     207  139616.41      91        3
# 9 2017-01-03  서남물재생센터   목욕장업        1     454  630328.07     199       54

# %% [markdown]
# # 목욕장업 인허가 전처리 코드 기반 함수로 모듈화

# %% [markdown]
# ### 🇰🇷 주소 전처리 · 표준화 · 좌표/행정동 파이프라인 (함수화 버전)
#
# 이 노트북은 아래 과정을 **함수화**하여 재사용 가능하게 구성했습니다.
#
# 1. **소재지전체주소/도로명전체주소** 상호 보완 및 패턴 전처리 (토큰 4개까지, `,` 이후 제거 등)
# 2. **행안부 JUSO 표준화 API**를 활용한 표준 도로명주소 생성 (캐시·재시도·병렬처리)
# 3. **카카오 주소→좌표** 지오코딩으로 `lon/lat` 채움 (캐시·재시도·병렬처리)
# 4. (가능 시) **EPSG:5174 → WGS84** 좌표 변환(`pyproj`) 및 보강
# 5. **카카오 좌표→행정/법정동** 역지오코딩으로 `행정동`, `행정동코드`, `법정동명`, `법정동코드` 추가
#
# > ⚙️ **모듈형 설계**: `AddressEnricher` 클래스로 구성되어, API 키/동시성/타임아웃 등을 파라미터로 제어할 수 있습니다.
#
#
# 맞아요.
#
# `AddressEnricher` 클래스 안에
#
# * 주소 전처리 제외한 **표준화, 좌표 변환, 지오코딩, 역지오코딩** 전 과정을 함수 형태로 다 넣어둔 거예요.
#
# 정리하면 구조가 이렇게 돼요:
#
# ```
# preprocess_address_columns()       # 전처리: 소재지/도로명 상호보완, 토큰 컷, 콤마 이후 제거
# AddressEnricher
#  ├─ _juso_standardize_one()        # 행안부 API 한 건 표준화 (캐시+재시도)
#  ├─ _candidate_sequence()          # 후보 주소 시퀀스 생성
#  ├─ standardize_addresses()        # 표준주소 컬럼 채우기 (병렬)
#  ├─ tm5174_to_wgs84()               # EPSG:5174 → WGS84 변환
#  ├─ _kakao_geocode()                # 카카오 주소→좌표
#  ├─ fill_coordinates()              # 좌표 채우기 (5174 변환 + 카카오)
#  ├─ _coord2region()                 # 카카오 좌표→행정/법정동
#  ├─ fill_regions()                  # 행정/법정동 채우기
#  └─ run_pipeline()                  # 전처리 → 표준화 → 좌표 → 행정동까지 원샷 실행
# ```
#
# 즉,
#
# * **전처리 함수**(`preprocess_address_columns`)는 클래스 밖에 따로 뺐고,
# * 나머지 주소 API 관련 로직은 전부 클래스 내부 메서드로 묶은 형태입니다.
#
# 그래서 실제 사용 시에는 이렇게 호출하면 전체가 한 번에 돌아갑니다:
#
# ```python
# enricher = AddressEnricher(juso_key=JUSO_KEY, kakao_key=KAKAO_KEY)
# result_df = enricher.run_pipeline(data)
# ```
#
# 원하시면 `preprocess_address_columns`까지 클래스 안으로 넣어서 **완전 일체형 클래스**로 만들어드릴 수도 있어요.
# 그렇게 하면 외부에서 함수 하나만 호출해도 전 과정이 클래스로만 처리됩니다.

# %%
# -*- coding: utf-8 -*-
# 모든 셀은 풍부한 주석과 함께 작성되었습니다.

import re
import time
import threading
import requests
import pandas as pd
from typing import Optional, Tuple, Dict, Any, List
from concurrent.futures import ThreadPoolExecutor, as_completed

# pyproj는 선택사항입니다. 설치되어 있지 않으면 좌표 변환 단계를 자동으로 건너뜁니다.
def _try_import_pyproj():
    try:
        from pyproj import Transformer  # type: ignore
        return Transformer
    except Exception:
        return None

Transformer = _try_import_pyproj()

# %%
def norm_addr(s: Any) -> Optional[str]:
    """
    주소 문자열의 기본 정규화
    - 문자열이 아니면 None
    - 양 끝 공백 제거, 중복 공백을 단일 공백으로 축소
    - 결과가 빈 문자열이면 None
    """
    if not isinstance(s, str):
        return None
    s = re.sub(r"\s+", " ", s.strip())
    return s if s else None


def remove_trailing_bunji(s: Any) -> Optional[str]:
    """
    문자열이 '...번지'로 정확히 끝나면 해당 어미만 제거.
    카카오/행안부 매칭률을 높이기 위한 후보 다양화 목적.
    """
    if not isinstance(s, str):
        return None
    s = s.strip()
    return s[:-2].strip() if s.endswith("번지") else s


def cut_before_last_dash(s: Any) -> Optional[str]:
    """
    마지막 '-' 앞까지만 남김.
    예: '67-138'→'67', '257-48번지'→'257번지'
    세부 부번/호수 제거로 매칭률을 높이는 전략.
    """
    if not isinstance(s, str):
        return None
    m = re.search(r"^(.*?)(?:-\d+)(?:번지)?\s*$", s)
    return m.group(1).strip() if m else s


def progressive_shrink(s: Any, max_try: int = 12) -> List[str]:
    """
    뒤에서 1글자씩 줄여가며 후보 생성 (과도한 축소 방지).
    경험적으로 '...구' 지점까지는 남기는 것이 매칭에 유리하여 컷오프 반영.
    """
    s0 = norm_addr(s)
    if not s0:
        return []
    min_len = max(8, s0.find("구") + 1)  # '...구'까지는 남기자
    out, cur = [], s0
    for _ in range(max_try):
        if len(cur) <= min_len:
            break
        cur = cur[:-1].rstrip()
        out.append(cur)
    return out

# %%
def preprocess_address_columns(
    df: pd.DataFrame,
    lot_col: str = "소재지전체주소",
    road_col: str = "도로명전체주소",
    keep_tokens: int = 4,
) -> pd.DataFrame:
    """
    1) 두 주소 컬럼 상호 보완(NaN → 다른 컬럼 값으로 채움)
    2) 공백 기준 상위 N 토큰까지만 유지(건물 주소까지만)
    3) ',' 기준 뒤쪽 상세 제거 및 strip
    
    원본 df를 변경하지 않기 위해 복사본을 반환합니다.
    """
    df = df.copy()

    # 상호 보완
    df[lot_col] = df[lot_col].fillna(df[road_col])
    df[road_col] = df[road_col].fillna(df[lot_col])

    # 토큰 컷
    df[lot_col] = df[lot_col].astype(str).str.split().str[:keep_tokens].str.join(' ')
    df[road_col] = df[road_col].astype(str).str.split().str[:keep_tokens].str.join(' ')

    # ',' 이후 제거 + 공백 정리
    df[lot_col] = df[lot_col].str.split(',').str.get(0).str.strip()
    df[road_col] = df[road_col].str.split(',').str.get(0).str.strip()

    return df

# %%
class AddressEnricher:
    """
    행안부(JUSO) 표준화 + 카카오(주소→좌표, 좌표→행정동) 파이프라인.
    
    Parameters
    ----------
    juso_key : str
        행안부 주소 표준화 API 키
    kakao_key : str
        카카오 로컬 API 키 (KakaoAK ...)
    conc_juso : int, default 12
        행안부 병렬 요청 수
    conc_kakao : int, default 25
        카카오 병렬 요청 수
    timeout : int, default 7
        각 요청 타임아웃(초)
    max_retry : int, default 3
        실패 시 재시도 횟수 (총 시도 = max_retry+1)
    max_shrink : int, default 12
        progressive_shrink 최대 시도 수
    """

    def __init__(
        self,
        juso_key: str,
        kakao_key: str,
        conc_juso: int = 12,
        conc_kakao: int = 25,
        timeout: int = 7,
        max_retry: int = 3,
        max_shrink: int = 12,
    ):
        self.JUSO_URL = "https://www.juso.go.kr/addrlink/addrLinkApi.do"
        self.ADDR_URL = "https://dapi.kakao.com/v2/local/search/address.json"
        self.REGION_URL = "https://dapi.kakao.com/v2/local/geo/coord2regioncode.json"
        self.juso_key = juso_key
        self.kakao_key = kakao_key
        self.headers = {"Authorization": f"KakaoAK {kakao_key}"}
        self.conc_juso = conc_juso
        self.conc_kakao = conc_kakao
        self.timeout = timeout
        self.max_retry = max_retry
        self.max_shrink = max_shrink

        # 캐시 & 락
        self.std_cache: Dict[str, Optional[str]] = {}
        self.std_lock = threading.Lock()

        self.addr_cache: Dict[str, Tuple[Optional[float], Optional[float]]] = {}
        self.addr_lock = threading.Lock()

        self.rc_cache: Dict[Tuple[float, float], Dict[str, Optional[str]]] = {}
        self.rc_lock = threading.Lock()

        # 좌표 변환기 (옵션)
        self._transformer = None
        if Transformer is not None:
            try:
                self._transformer = Transformer.from_crs(5174, 4326, always_xy=True)
            except Exception:
                self._transformer = None

    # ------------------------- 표준화 -------------------------
    def _juso_standardize_one(self, addr: Optional[str]) -> Tuple[Optional[str], Optional[str]]:
        """
        입력 주소 → (정규화된입력, 표준도로명주소 or None)
        내부 캐시 사용 + 재시도 로직.
        """
        if not addr:
            return addr, None
        a = norm_addr(addr)
        if not a:
            return addr, None
        with self.std_lock:
            if a in self.std_cache:
                return a, self.std_cache[a]

        params = {
            'confmKey': self.juso_key,
            'currentPage': 1,
            'countPerPage': 1,
            'keyword': a,
            'resultType': 'json'
        }
        out = None
        for attempt in range(1, self.max_retry + 2):
            try:
                r = requests.get(self.JUSO_URL, params=params, timeout=self.timeout)
                r.raise_for_status()
                j = r.json().get('results', {}).get('juso', [])
                out = j[0].get('roadAddr') if j else None
                break
            except Exception:
                if attempt == self.max_retry + 1:
                    out = None
                else:
                    time.sleep(0.5 * attempt)

        with self.std_lock:
            self.std_cache[a] = out
        return a, out

    def _candidate_sequence(self, row: pd.Series, lot_col: str, road_col: str) -> List[str]:
        """각 행에 대해 표준화 후보 문자열 시퀀스 생성"""
        raw_road = remove_trailing_bunji(norm_addr(row.get(road_col)))
        raw_lot  = remove_trailing_bunji(norm_addr(row.get(lot_col)))

        cand: List[str] = []
        for a in [raw_road, raw_lot]:
            if a and a not in cand:
                cand.append(a)

        if raw_lot:
            cut = cut_before_last_dash(raw_lot)
            if cut and cut not in cand and cut != raw_lot:
                cand.append(cut)
            for shr in progressive_shrink(raw_lot, self.max_shrink):
                if shr not in cand:
                    cand.append(shr)
        return cand

    def standardize_addresses(
        self,
        df: pd.DataFrame,
        lot_col: str = "소재지전체주소",
        road_col: str = "도로명전체주소",
        out_col: str = "표준도로명주소",
        verbose: bool = True,
    ) -> pd.DataFrame:
        """행안부 API로 표준 도로명주소 생성 후 out_col에 저장"""
        df = df.copy()
        if out_col not in df.columns:
            df[out_col] = None
        need = df[out_col].isna()

        # 후보 생성
        cseq = df.loc[need].apply(self._candidate_sequence, axis=1, args=(lot_col, road_col))

        # unique 후보 리스트
        all_candidates: List[str] = []
        for lst in cseq:
            all_candidates.extend(lst)
        uniq_candidates = list(dict.fromkeys([a for a in all_candidates if a]))

        if verbose:
            print("유니크 후보 수:", len(uniq_candidates))

        # 병렬 호출
        t0 = time.time()
        with ThreadPoolExecutor(max_workers=self.conc_juso) as ex:
            futures = [ex.submit(self._juso_standardize_one, a) for a in uniq_candidates]
            for i, f in enumerate(as_completed(futures), 1):
                _ = f.result()
                if verbose and (i % 200 == 0 or i == len(uniq_candidates)):
                    dt = time.time() - t0
                    print(f"[JUSO 호출] {i}/{len(uniq_candidates)} | {i/max(dt,1):.1f} req/s")

        # 첫 성공값 채우기
        filled = 0
        for idx, lst in cseq.items():
            std = None
            for a in lst:
                key = norm_addr(a)
                std = self.std_cache.get(key)
                if std:
                    break
            if std:
                df.at[idx, out_col] = std
                filled += 1

        if verbose:
            print(f"이번 라운드 채워짐: {filled}")
            print("표준도로명주소 결측:", int(df[out_col].isna().sum()), "/", len(df))
        return df

    # ------------------------- 좌표 변환 -------------------------
    def tm5174_to_wgs84(self, x: Any, y: Any) -> Tuple[Optional[float], Optional[float]]:
        """EPSG:5174 → WGS84(lon, lat) 변환 (변환기 없거나 실패 시 (None, None))"""
        if pd.isna(x) or pd.isna(y) or self._transformer is None:
            return (None, None)
        try:
            lon, lat = self._transformer.transform(float(x), float(y))
            return (float(lon), float(lat))
        except Exception:
            return (None, None)

    # ------------------------- 카카오 주소→좌표 -------------------------
    def _kakao_geocode(self, addr: Optional[str]) -> Tuple[Optional[float], Optional[float]]:
        if not isinstance(addr, str) or not addr.strip():
            return (None, None)
        a = norm_addr(addr)
        with self.addr_lock:
            if a in self.addr_cache:
                return self.addr_cache[a]
        out = (None, None)
        for attempt in range(1, self.max_retry + 2):
            try:
                r = requests.get(self.ADDR_URL, headers=self.headers, params={"query": a}, timeout=self.timeout)
                r.raise_for_status()
                docs = r.json().get("documents", [])
                out = (float(docs[0]['x']), float(docs[0]['y'])) if docs else (None, None)
                break
            except Exception:
                if attempt == self.max_retry + 1:
                    out = (None, None)
                else:
                    time.sleep(0.4 * attempt)
        with self.addr_lock:
            self.addr_cache[a] = out
        return out

    def fill_coordinates(
        self,
        df: pd.DataFrame,
        std_col: str = "표준도로명주소",
        x5174_col: str = "좌표정보x(epsg5174)",
        y5174_col: str = "좌표정보y(epsg5174)",
        lon_col: str = "lon",
        lat_col: str = "lat",
        verbose: bool = True,
    ) -> pd.DataFrame:
        """5174→WGS84 변환으로 lon/lat 채우고, 남은 결측은 카카오 주소→좌표로 보강"""
        df = df.copy()
        if x5174_col not in df.columns:
            df[x5174_col] = None
        if y5174_col not in df.columns:
            df[y5174_col] = None

        # 5174 → WGS84 (가능할 때만)
        xy = df[[x5174_col, y5174_col]].apply(lambda r: self.tm5174_to_wgs84(r[x5174_col], r[y5174_col]), axis=1)
        df[lon_col] = [p[0] for p in xy]
        df[lat_col] = [p[1] for p in xy]

        if verbose:
            print("기존좌표 변환 후 결측(lon/lat):", int((df[lon_col].isna() | df[lat_col].isna()).sum()))

        # 카카오 지오코딩 (결측만)
        need_geo = df[lon_col].isna() | df[lat_col].isna()
        uniq_std = df.loc[need_geo, std_col].dropna().unique().tolist()

        t2 = time.time()
        with ThreadPoolExecutor(max_workers=self.conc_kakao) as ex:
            futures = [ex.submit(self._kakao_geocode, a) for a in uniq_std]
            for i, f in enumerate(as_completed(futures), 1):
                _ = f.result()
                if verbose and (i % 200 == 0 or i == len(uniq_std)):
                    dt = time.time() - t2
                    print(f"[카카오 지오코딩] {i}/{len(uniq_std)} | {i/max(dt,1):.1f} req/s")

        # 결과 매핑
        df.loc[need_geo, lon_col] = df.loc[need_geo, std_col].map(
            lambda a: self.addr_cache.get(norm_addr(a), (None, None))[0]
        ).astype('float64').values
        df.loc[need_geo, lat_col] = df.loc[need_geo, std_col].map(
            lambda a: self.addr_cache.get(norm_addr(a), (None, None))[1]
        ).astype('float64').values

        if verbose:
            print("최종 좌표 결측:", int((df[lon_col].isna() | df[lat_col].isna()).sum()))
        return df

    # ------------------------- 카카오 좌표→행정/법정동 -------------------------
    def _coord2region(self, lon: Any, lat: Any) -> Dict[str, Optional[str]]:
        if pd.isna(lon) or pd.isna(lat):
            return {"행정동": None, "행정동코드": None, "법정동명": None, "법정동코드": None}
        key = (float(lon), float(lat))
        with self.rc_lock:
            if key in self.rc_cache:
                return self.rc_cache[key]
        out = {"행정동": None, "행정동코드": None, "법정동명": None, "법정동코드": None}
        for attempt in range(1, self.max_retry + 2):
            try:
                r = requests.get(self.REGION_URL, headers=self.headers, params={"x": key[0], "y": key[1]},
                                 timeout=self.timeout)
                r.raise_for_status()
                docs = r.json().get("documents", [])
                h = next((d for d in docs if d.get('region_type') == 'H'), None)
                b = next((d for d in docs if d.get('region_type') == 'B'), None)
                out = {
                    "행정동": (h or {}).get("region_3depth_name"),
                    "행정동코드": (h or {}).get("code"),
                    "법정동명": (b or {}).get("region_3depth_name"),
                    "법정동코드": (b or {}).get("code"),
                }
                break
            except Exception:
                if attempt == self.max_retry + 1:
                    pass
                else:
                    time.sleep(0.4 * attempt)
        with self.rc_lock:
            self.rc_cache[key] = out
        return out

    def fill_regions(
        self,
        df: pd.DataFrame,
        lon_col: str = "lon",
        lat_col: str = "lat",
        verbose: bool = True,
    ) -> pd.DataFrame:
        """좌표로부터 행정/법정동 메타데이터 채움"""
        df = df.copy()

        pairs = pd.Series(list(zip(df[lon_col], df[lat_col]))).dropna().unique().tolist()

        t3 = time.time()
        with ThreadPoolExecutor(max_workers=self.conc_kakao) as ex:
            futures = [ex.submit(self._coord2region, *p) for p in pairs]
            for i, f in enumerate(as_completed(futures), 1):
                _ = f.result()
                if verbose and (i % 300 == 0 or i == len(pairs)):
                    dt = time.time() - t3
                    print(f"[행정동 조회] {i}/{len(pairs)} | {i/max(dt,1):.1f} req/s")

        tmp = df[[lon_col, lat_col]].apply(
            lambda r: self.rc_cache.get((r[lon_col], r[lat_col]),
                {"행정동": None, "행정동코드": None, "법정동명": None, "법정동코드": None}
            ),
            axis=1
        )
        meta = pd.json_normalize(tmp)
        for c in ["행정동", "행정동코드", "법정동명", "법정동코드"]:
            df[c] = meta.get(c)
        if verbose:
            print("총 건수:", len(df), " | 행정동 결측:", int(df['행정동'].isna().sum()))
        return df

    # ------------------------- 원샷 파이프라인 -------------------------
    def run_pipeline(
        self,
        df: pd.DataFrame,
        lot_col: str = "소재지전체주소",
        road_col: str = "도로명전체주소",
        std_col: str = "표준도로명주소",
        x5174_col: str = "좌표정보x(epsg5174)",
        y5174_col: str = "좌표정보y(epsg5174)",
        lon_col: str = "lon",
        lat_col: str = "lat",
        keep_tokens: int = 4,
        verbose: bool = True,
    ) -> pd.DataFrame:
        """전처리 → 표준화 → 좌표 채움 → 행정/법정동 채움까지 원샷 실행"""
        step1 = preprocess_address_columns(df, lot_col=lot_col, road_col=road_col, keep_tokens=keep_tokens)
        step2 = self.standardize_addresses(step1, lot_col=lot_col, road_col=road_col, out_col=std_col, verbose=verbose)
        step3 = self.fill_coordinates(step2, std_col=std_col, x5174_col=x5174_col, y5174_col=y5174_col,
                                      lon_col=lon_col, lat_col=lat_col, verbose=verbose)
        step4 = self.fill_regions(step3, lon_col=lon_col, lat_col=lat_col, verbose=verbose)
        return step4

# %%
# ==============================
# 사용 예시 (API 키를 설정한 후 실행)
# ==============================
# 주의: 이 셀은 함수/클래스 정의 이후에 테스트할 때만 실행하세요.

# 예시 데이터프레임 (실 데이터로 교체)
# data = pd.DataFrame({
#     '소재지전체주소': ['서울특별시 강남구 역삼동 123-45', None],
#     '도로명전체주소': [None, '서울특별시 강남구 테헤란로 123'],
#     '좌표정보x(epsg5174)': [None, None],
#     '좌표정보y(epsg5174)': [None, None],
# })

# ★ 본인 API 키 입력 ★
# JUSO_KEY  = "<행안부-키>"
# KAKAO_KEY = "<카카오-REST-API-키>"

# enricher = AddressEnricher(juso_key=JUSO_KEY, kakao_key=KAKAO_KEY)
# result = enricher.run_pipeline(data, keep_tokens=4, verbose=True)
# result.head()

# %% [markdown]
# # 2. 수영장업 인허가 데이터
# - 수영장 등 수영 같은 레크레이션을 즐기기 위해 인공적으로 물을 채워 제공하는 업소정보
# - 6110000_서울특별시_10_35_01_P_수영장업.csv

# %%
data = pd.read_csv('../data/raw/add/6110000_CSV/6110000_서울특별시_10_35_01_P_수영장업.csv', encoding='cp949')
data
# Out:
#       번호 개방서비스명    개방서비스아이디  개방자치단체코드                  관리번호       인허가일자  \
# 0      1   수영장업  10_35_01_P   3000000  CDFH3301011995000001  1995-06-30
# 1      2   수영장업  10_35_01_P   3000000  CDFH3301011999000001  1999-12-22
# 2      3   수영장업  10_35_01_P   3000000  CDFH3301012005000001  2005-02-23
# 3      4   수영장업  10_35_01_P   3000000  CDFH3301012007000001  2007-01-30
# 4      5   수영장업  10_35_01_P   3010000  CDFH3301011990000002  1990-07-25
# ..   ...    ...         ...       ...                   ...         ...
# 242  243   수영장업  10_35_01_P   3240000  CDFH3301011990000001  1990-01-18
# 243  244   수영장업  10_35_01_P   3240000  CDFH3301012011000001  2011-10-24
# 244  245   수영장업  10_35_01_P   3240000  CDFH3301012013000001  2013-04-26
# 245  246   수영장업  10_35_01_P   3240000  CDFH3301012018000001  2018-05-15
# 246  247   수영장업  10_35_01_P   3240000  CDFH3301012017000001  2017-06-23
#
#     인허가취소일자  영업상태구분코드           영업상태명  상세영업상태코드  ... 문화체육업종명 공사립구분명 보험가입여부코드  \
# 0       NaN         3              폐업         3  ...    수영장업     사립        0
# 1       NaN         3              폐업         3  ...    수영장업     사립        0
# 2       NaN         4  취소/말소/만료/정지/중지        35  ...    수영장업     공립        Y
# 3       NaN         4  취소/말소/만료/정지/중지        35  ...    수영장업     사립        Y
# 4       NaN         3              폐업         3  ...    수영장업     사립      NaN
# ..      ...       ...             ...       ...  ...     ...    ...      ...
# 242     NaN         1           영업/정상        13  ...    수영장업     사립      NaN
# 243     NaN         1           영업/정상        13  ...    수영장업     사립      NaN
# 244     NaN         1           영업/정상        13  ...    수영장업     사립      NaN
# 245     NaN         1           영업/정상        13  ...    수영장업     사립      NaN
# 246     NaN         1           영업/정상        13  ...    수영장업     사립      NaN
#
#     지도자수  건축물동수   건축물연면적  회원모집총인원 세부업종명 법인명 Unnamed: 37
# 0    NaN    NaN      NaN      NaN   NaN NaN         NaN
# 1    NaN    NaN      NaN      NaN   NaN NaN         NaN
# 2    NaN    NaN  5442.97      NaN   NaN NaN         NaN
# 3    NaN    NaN      NaN      NaN   NaN NaN         NaN
# 4    NaN    NaN      NaN      NaN   NaN NaN         NaN
# ..   ...    ...      ...      ...   ...  ..         ...
# 242  NaN    NaN  3010.79      NaN   NaN NaN         NaN
# 243  1.0    1.0  2433.33    200.0   NaN NaN         NaN
# 244  1.0    1.0   542.17      0.0   NaN NaN         NaN
# 245  0.0    0.0     0.00      0.0   NaN NaN         NaN
# 246  1.0    0.0  3131.54      0.0   NaN NaN         NaN
#
# [247 rows x 38 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 38 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   번호               247 non-null    int64
#  1   개방서비스명           247 non-null    object
#  2   개방서비스아이디         247 non-null    object
#  3   개방자치단체코드         247 non-null    int64
#  4   관리번호             247 non-null    object
#  5   인허가일자            247 non-null    object
#  6   인허가취소일자          2 non-null      object
#  7   영업상태구분코드         247 non-null    int64
#  8   영업상태명            247 non-null    object
#  9   상세영업상태코드         247 non-null    int64
#  10  상세영업상태명          247 non-null    object
#  11  폐업일자             100 non-null    object
#  12  휴업시작일자           2 non-null      object
#  13  휴업종료일자           2 non-null      object
#  14  재개업일자            0 non-null      float64
#  15  소재지전화            203 non-null    object
#  16  소재지면적            0 non-null      float64
#  17  소재지우편번호          146 non-null    object
#  18  소재지전체주소          245 non-null    object
#  19  도로명전체주소          211 non-null    object
#  20  도로명우편번호          161 non-null    object
#  21  사업장명             247 non-null    object
#  22  최종수정시점           247 non-null    object
#  23  데이터갱신구분          247 non-null    object
#  24  데이터갱신일자          247 non-null    object
#  25  업태구분명            0 non-null      float64
#  26  좌표정보x(epsg5174)  239 non-null    float64
#  27  좌표정보y(epsg5174)  239 non-null    float64
#  28  문화체육업종명          247 non-null    object
#  29  공사립구분명           247 non-null    object
#  30  보험가입여부코드         113 non-null    object
#  31  지도자수             132 non-null    float64
#  32  건축물동수            84 non-null     float64
#  33  건축물연면적           127 non-null    float64
#  34  회원모집총인원          64 non-null     float64
#  35  세부업종명            0 non-null      float64
#  36  법인명              0 non-null      float64
#  37  Unnamed: 37      0 non-null      float64
# dtypes: float64(12), int64(4), object(22)
# memory usage: 73.5+ KB

# %%
### 폐업일자가 있고 & 2017-01-01 이전인 경우 제거

# 폐업일자 datetime 으로 변경
data['폐업일자'] = pd.to_datetime(data['폐업일자'], errors='coerce')

# 널값이 아니고 20170101 이전 폐업인 데이터 
mask_drop = data['폐업일자'].notna() & (data['폐업일자'] < pd.Timestamp('2017-01-01'))

# mask_drop 데이터가 아닌 행만 남기기
data = data[~mask_drop]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 177 entries, 2 to 246
# Data columns (total 38 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   번호               177 non-null    int64
#  1   개방서비스명           177 non-null    object
#  2   개방서비스아이디         177 non-null    object
#  3   개방자치단체코드         177 non-null    int64
#  4   관리번호             177 non-null    object
#  5   인허가일자            177 non-null    object
#  6   인허가취소일자          2 non-null      object
#  7   영업상태구분코드         177 non-null    int64
#  8   영업상태명            177 non-null    object
#  9   상세영업상태코드         177 non-null    int64
#  10  상세영업상태명          177 non-null    object
#  11  폐업일자             30 non-null     datetime64[ns]
#  12  휴업시작일자           2 non-null      object
#  13  휴업종료일자           2 non-null      object
#  14  재개업일자            0 non-null      float64
#  15  소재지전화            145 non-null    object
#  16  소재지면적            0 non-null      float64
#  17  소재지우편번호          77 non-null     object
#  18  소재지전체주소          175 non-null    object
#  19  도로명전체주소          165 non-null    object
#  20  도로명우편번호          154 non-null    object
#  21  사업장명             177 non-null    object
#  22  최종수정시점           177 non-null    object
#  23  데이터갱신구분          177 non-null    object
#  24  데이터갱신일자          177 non-null    object
#  25  업태구분명            0 non-null      float64
#  26  좌표정보x(epsg5174)  173 non-null    float64
#  27  좌표정보y(epsg5174)  173 non-null    float64
#  28  문화체육업종명          177 non-null    object
#  29  공사립구분명           177 non-null    object
#  30  보험가입여부코드         66 non-null     object
#  31  지도자수             115 non-null    float64
#  32  건축물동수            75 non-null     float64
#  33  건축물연면적           109 non-null    float64
#  34  회원모집총인원          64 non-null     float64
#  35  세부업종명            0 non-null      float64
#  36  법인명              0 non-null      float64
#  37  Unnamed: 37      0 non-null      float64
# dtypes: datetime64[ns](1), float64(12), int64(4), object(21)
# memory usage: 53.9+ KB
# C:\Users\user\AppData\Local\Temp\ipykernel_13416\1976514566.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['폐업일자'] = pd.to_datetime(data['폐업일자'], errors='coerce')

# %%
data.columns
# Out:
# Index(['번호', '개방서비스명', '개방서비스아이디', '개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자',
#        '영업상태구분코드', '영업상태명', '상세영업상태코드', '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자',
#        '재개업일자', '소재지전화', '소재지면적', '소재지우편번호', '소재지전체주소', '도로명전체주소', '도로명우편번호',
#        '사업장명', '최종수정시점', '데이터갱신구분', '데이터갱신일자', '업태구분명', '좌표정보x(epsg5174)',
#        '좌표정보y(epsg5174)', '문화체육업종명', '공사립구분명', '보험가입여부코드', '지도자수', '건축물동수',
#        '건축물연면적', '회원모집총인원', '세부업종명', '법인명', 'Unnamed: 37'],
#       dtype='object')

# %%
data = data.drop(['번호','개방서비스아이디', '개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자',
        '영업상태구분코드', '영업상태명', '상세영업상태코드', '휴업시작일자', '휴업종료일자',
       '재개업일자', '소재지전화', '소재지면적', '소재지우편번호', '도로명우편번호','최종수정시점', '데이터갱신구분', '데이터갱신일자',
       '업태구분명','문화체육업종명', '세부업종명', '법인명', 'Unnamed: 37'
       ], axis=1)

data
# Out:
#     개방서비스명 상세영업상태명       폐업일자                         소재지전체주소  \
# 2     수영장업    직권말소 2020-03-13             서울특별시 종로구 청운동 123번지
# 6     수영장업     영업중        NaT               서울특별시 중구 명동1가 1-1
# 7     수영장업     영업중        NaT            서울특별시 중구 장충동2가 산 5-5
# 8     수영장업     영업중        NaT              서울특별시 중구 순화동 2-6번지
# 9     수영장업     영업중        NaT             서울특별시 중구 흥인동 13-1번지
# ..     ...     ...        ...                             ...
# 242   수영장업     영업중        NaT             서울특별시 강동구 상일동 126번지
# 243   수영장업     영업중        NaT          서울특별시 강동구 성내동 445-7 지층
# 244   수영장업     영업중        NaT            서울특별시 강동구 명일동 305-39
# 245   수영장업     영업중        NaT         서울특별시 강동구 강일동 679 중앙프라자
# 246   수영장업     영업중        NaT  서울특별시 강동구 명일동 48-14 메가빌딩 지하 1층
#
#                                     도로명전체주소                              사업장명  \
# 2              서울특별시 종로구 자하문로 105, 2층 (청운동)                           청운스포츠센터
# 6                                       NaN                      서울YWCA 스포츠센터
# 7                                       NaN  Banyan Tree Club&SPA Seoul Oasis
# 8                                       NaN                 중앙일보교육사업단(중앙문화센터)
# 9                                       NaN                          뉴)월드스포랜드
# ..                                      ...                               ...
# 242              서울특별시 강동구 구천면로93길 12 (상일동)                       한국시각장애인복지재단
# 243          서울특별시 강동구 양재대로81길 64, 지층 (성내동)                             키즈토피아
# 244               서울특별시 강동구 양재대로 1665 (명일동)                              오션키즈
# 245         서울특별시 강동구 아리수로 427, 중앙프라자 (강일동)                              나우수영
# 246  서울특별시 강동구 동남로71길 24, 메가빌딩 지하 1층층 (명일동)                            아이키즈스윔
#
#      좌표정보x(epsg5174)  좌표정보y(epsg5174) 공사립구분명 보험가입여부코드  지도자수  건축물동수   건축물연면적  \
# 2      197224.271407    453711.382152     공립        Y   NaN    NaN  5442.97
# 6      198705.527320    451401.164804     사립        0   0.0    0.0     0.00
# 7      200193.232425    449809.744685     사립      NaN   0.0    0.0     0.00
# 8      197395.761334    451285.616478     사립        0   NaN    NaN      NaN
# 9      201442.039019    451619.845549     사립        0   NaN    NaN      NaN
# ..               ...              ...    ...      ...   ...    ...      ...
# 242    214866.322883    449869.026666     사립      NaN   NaN    NaN  3010.79
# 243    211510.777132    446882.690090     사립      NaN   1.0    1.0  2433.33
# 244    212643.005289    450239.699709     사립      NaN   1.0    1.0   542.17
# 245    215356.343213    451422.369618     사립      NaN   0.0    0.0     0.00
# 246    213607.407455    449980.645505     사립      NaN   1.0    0.0  3131.54
#
#      회원모집총인원
# 2        NaN
# 6        0.0
# 7        0.0
# 8        NaN
# 9        NaN
# ..       ...
# 242      NaN
# 243    200.0
# 244      0.0
# 245      0.0
# 246      0.0
#
# [177 rows x 14 columns]

# %%
### 소재지전체주소, 도로명전체주소 상호보완 및 전처리 함수 ###
def preprocess_address()
# Out:
# 개방서비스명               0
# 상세영업상태명              0
# 폐업일자               147
# 소재지전체주소              0
# 도로명전체주소              0
# 사업장명                 0
# 좌표정보x(epsg5174)      4
# 좌표정보y(epsg5174)      4
# 공사립구분명               0
# 보험가입여부코드           111
# 지도자수                62
# 건축물동수              102
# 건축물연면적              68
# 회원모집총인원            113
# dtype: int64

# %% [markdown]
# # 3. 세탁업 인허가 데이터
# - 빨래방, 세탁소, 운동화빨래방 등 의류 기타섬유제품이나 피혁제품등을 세탁하는 업소 정보
# - 6110000_서울특별시_06_20_01_P_세탁업.csv

# %%
data = pd.read_csv('../data/raw/add/6110000_CSV/6110000_서울특별시_06_20_01_P_세탁업.csv', encoding='cp949')
data

# %%
data['폐업일자'] = pd.to_datetime(data['폐업일자'], errors='coerce')

# 폐업일자가 있고 & 2017-01-01 이전인 경우 제거
mask_drop = data['폐업일자'].notna() & (data['폐업일자'] < pd.Timestamp('2017-01-01'))

data = data[~mask_drop]
data.info()

# %% [markdown]
# # 4. 종합체육시설업 인허가 데이터
# - 수영, 골프, 체육단련 등과 같은 체육시설을 한 곳에 모아놓은 업소정보
# - 6110000_서울특별시_10_37_01_P_종합체육시설업.csv

# %%
data = pd.read_csv('../data/raw/add/6110000_CSV/6110000_서울특별시_10_37_01_P_종합체육시설업.csv', encoding='cp949')
data

# %%
data['폐업일자'] = pd.to_datetime(data['폐업일자'], errors='coerce')

# 폐업일자가 있고 & 2017-01-01 이전인 경우 제거
mask_drop = data['폐업일자'].notna() & (data['폐업일자'] < pd.Timestamp('2017-01-01'))

data = data[~mask_drop]
data.info()

# %% [markdown]
# # 5. 체력단련장업 인허가 데이터
# - 헬스장과 같은 체격관리 및 근력, 유연성, 지구력 강화 등을 목표로 운동을 할 때 필요한 도구와 기구를 제공하는 업소정보
# - 샤워실 보통 포함하기 때문에 확인
# - 6110000_서울특별시_10_42_01_P_체력단련장업.csv

# %%
data = pd.read_csv('../data/raw/add/6110000_CSV/6110000_서울특별시_10_42_01_P_체력단련장업.csv', encoding='cp949')
data

# %%
data['폐업일자'] = pd.to_datetime(data['폐업일자'], errors='coerce')

# 폐업일자가 있고 & 2017-01-01 이전인 경우 제거
mask_drop = data['폐업일자'].notna() & (data['폐업일자'] < pd.Timestamp('2017-01-01'))

data = data[~mask_drop]
data.info()

# %% [markdown]
# # 6. 미용업, 이용업 인허가 데이터
# - 미용업 : 헤어, 메이크업, 네일아트와 같이 얼굴, 머리, 피부 등을 손질하여 외모를 아름답게 꾸미는 업소정보
# - 6110000_서울특별시_05_18_01_P_미용업.csv
# - 이용업 : 이발소와 같이 머리 또는 수염을 깎거나 다듬는 등의 방법으로 용모를 단정하게하는 업소정보
# - 6110000_서울특별시_05_19_01_P_이용업.csv

# %%
data1 = pd.read_csv('../data/raw/add/6110000_CSV/6110000_서울특별시_05_18_01_P_미용업.csv', encoding='cp949')
data2 = pd.read_csv('../data/raw/add/6110000_CSV/6110000_서울특별시_05_19_01_P_이용업.csv', encoding='cp949')
data1, data2

# %%
data['폐업일자'] = pd.to_datetime(data['폐업일자'], errors='coerce')

# 폐업일자가 있고 & 2017-01-01 이전인 경우 제거
mask_drop = data['폐업일자'].notna() & (data['폐업일자'] < pd.Timestamp('2017-01-01'))

data = data[~mask_drop]
data.info()
