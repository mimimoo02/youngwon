# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../results/서울_AWS_merged_20230101_20250630.csv', encoding='utf-8-sig')
df
# Out:
#         지점  지점명          날짜   평균기온(°C)  최저기온(°C)  최고기온(°C)  일강수량(mm)  \
# 0      400   강남  2023-01-01   1.000000      -2.3       4.8       0.0
# 1      400   강남  2023-01-02  -2.987500      -5.2      -0.5       0.0
# 2      400   강남  2023-01-03  -3.695833      -8.3       0.7       0.0
# 3      400   강남  2023-01-04  -1.366667      -6.2       4.1       0.0
# 4      400   강남  2023-01-05  -1.970833      -6.2       3.5       0.0
# ...    ...  ...         ...        ...       ...       ...       ...
# 24619  889  현충원  2025-06-26  22.300000      20.2      25.4       0.5
# 24620  889  현충원  2025-06-27  24.845833      20.3      30.2       0.0
# 24621  889  현충원  2025-06-28  26.408333      24.0      29.1       0.0
# 24622  889  현충원  2025-06-29  27.479167      24.6      31.7       0.0
# 24623  889  현충원  2025-06-30  27.991667      23.9      31.8       0.0
#
#        평균풍속(m/s)    평균습도(%)  최저습도(%)  최고습도(%)     습도표준편차  일_평균기온(°C)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24624 entries, 0 to 24623
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   지점          24624 non-null  int64
#  1   지점명         24624 non-null  object
#  2   날짜          24624 non-null  object
#  3   평균기온(°C)    24624 non-null  float64
#  4   최저기온(°C)    24624 non-null  float64
#  5   최고기온(°C)    24624 non-null  float64
#  6   일강수량(mm)    24624 non-null  float64
#  7   평균풍속(m/s)   24624 non-null  float64
#  8   평균습도(%)     24624 non-null  float64
#  9   최저습도(%)     24624 non-null  float64
#  10  최고습도(%)     24624 non-null  float64
#  11  습도표준편차      24624 non-null  float64
#  12  일_평균기온(°C)  24624 non-null  float64
#  13  일_최저기온(°C)  24624 non-null  float64
#  14  일_최고기온(°C)  24624 non-null  float64
#  15  일_일강수량(mm)  24624 non-null  float64
#  16  주소          24624 non-null  object
#  17  위도          24624 non-null  float64
# ...

# %%
df['날짜'] = pd.to_datetime(df['날짜'])
df['요일'] = df['날짜'].dt.weekday # 월요일 :0, 화:1, ..., 일:6

df[['날짜', '요일']]
# Out:
#               날짜  요일
# 0     2023-01-01   6
# 1     2023-01-02   0
# 2     2023-01-03   1
# 3     2023-01-04   2
# 4     2023-01-05   3
# ...          ...  ..
# 24619 2025-06-26   3
# 24620 2025-06-27   4
# 24621 2025-06-28   5
# 24622 2025-06-29   6
# 24623 2025-06-30   0
#
# [24624 rows x 2 columns]
